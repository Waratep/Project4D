# %%
def region_of_interest(img, vertices):   
    mask = np.zeros_like(img)
    match_mask_color = (255,)
    cv2.fillPoly(mask, vertices, 255)
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image

def slope(start,end,width):
    x1=start[0]
    x2=end[0]
    y1=width-start[1]
    y2=width-end[1]
    if (x2-x1) != 0:
        m=(y2-y1)/(x2-x1)        
        return m
    
def findSlope(start,end,width):
    x1 = start[0]
    x2 = end[0]
    y1 = width-start[1]
    y2 = width-end[1]
    if (x2 - x1) != 0:
        m = (y2-y1)/(x2-x1)
        return m 
    
def debug(width,height,slope_left,slope_right):
    print('width:',width,', height:',height)
    print('slope_left:', slope_left)
    print('slope_right:', slope_right)
    print('slope: ', round(slope_right+slope_left,3))
    print()

# %%
import cv2
import numpy as np
import time
from skimage.io import imshow,imread,imsave
from scipy import ndimage as ndi
from skimage import feature
from matplotlib import pyplot as plt
from skimage.morphology import square,dilation
#300 , 10 , 410
show=[]
image = cv2.imread('../dataset/original/10.jpg')
image1 = cv2.imread('../dataset/original/300.jpg')
countR = 0
# resize image
frame = cv2.resize(image,(100, 75))  
# frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
height=frame.shape[0]
width=frame.shape[1]
region_of_interest_vertices = [   
    (0, height),
    (0, (height/3)+10),
#         ((width/6), (height/3)+15),
#     (width-(width/6), (height/3)+15),
    (width, (height/3)+10),
    (width, height)]


gray=cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
edges = cv2.Canny(gray,100,200)
edges = dilation(edges, square(3))
# edges[:,width-3:width] = 0 
# edges = ndi.gaussian_filter(edges,2)

crop = region_of_interest(edges,np.array([region_of_interest_vertices], np.int32))
frame=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    
lowerR=np.array([220,70,70])
upperR=np.array([255,160,170])    
maskR = cv2.inRange(frame, lowerR, upperR)

for i in range(width):        
    if maskR[int(height/3)][i] == 255: 
        countR+=1
    if countR > 10:
        print('stop')
        break

# Hough Transform
lines = cv2.HoughLinesP(crop,rho = 1,theta = 1*np.pi/180,threshold = 40,minLineLength = 10,maxLineGap = 250)
font = cv2.FONT_HERSHEY_SIMPLEX
l=[]
r=[]

# Draw lines on the image
if(lines is not None) :
    for line in lines:  
        x1, y1, x2, y2 = line[0]
        if(findSlope((x1,y1),(x2,y2),width)):
            if(x1 < int(width/2)):
                l.append([x1,x2,y1,y2,findSlope((x1,y1),(x2,y2),width)])
                cv2.line(frame, (x1, y1), (x2, y2), (255, 0, 0), 3)
            else:
                r.append([x1,x2,y1,y2,findSlope((x1,y1),(x2,y2),width)])
                cv2.line(frame, (x1, y1), (x2, y2), (0, 0, 255), 3)

    l=np.array(l)
    r=np.array(r)
#     slope_leftP = slope_left
#     slope_rightP = slope_right
    # slope left
    if(len(l)):                
        slope_left = round(sum(l[:,4])/len(l),2)  
        x1 = round(sum(l[:,0])/len(l)).astype('int')
        x2 = round(sum(l[:,1])/len(l)).astype('int')
        y1 = round(sum(l[:,2])/len(l)).astype('int')
        y2 = round(sum(l[:,3])/len(l)).astype('int')
#         cv2.line(frame, (x1, y1), (x2, y2), (255, 0, 0), 3)
    else:
        slope_left = self.slope_leftP

    # slope right
    if(len(r)):                
        slope_right = round(sum(r[:,4])/len(r),2)
        x1 = round(sum(r[:,0])/len(r)).astype('int')
        x2 = round(sum(r[:,1])/len(r)).astype('int')
        y1 = round(sum(r[:,2])/len(r)).astype('int')
        y2 = round(sum(r[:,3])/len(r)).astype('int')
#         cv2.line(frame, (x1, y1), (x2, y2), (0, 0, 255), 3)
    else:
        slope_right = self.slope_rightP


    slope = round(slope_right + slope_left,3)
    if(slope > 2):
        slope = 2
    elif(slope < -2):
        slope = -2  

    frame=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  
#     cv2.putText(frame,str(slope),(10,20), font, 0.5,(255,255,255),1,cv2.LINE_AA)
    

show.append(image)
show.append(cv2.resize(image,(100, 75)))
show.append(maskR)
show.append(gray)
show.append(crop)
show.append(frame)
# imshow_collection(show)
num=0
for f in show:
    plt.figure()
    cv2.imwrite('../dataset/ppt/'+str(num)+'.jpg',f)
    num+=1
    imshow(f)
print(lines)
# debug(width,height,slope_left,slope_right)
# Out:
# C:\Users\Bermuda\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\Bermuda\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)
# C:\Users\Bermuda\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "
# [[[ 3 74 23 35]]
#
#  [[10 74 24 35]]
#
#  [[12 74 26 35]]
#
#  [[77 35 97 74]]
#
#  [[76 35 91 74]]]

# %%
fourcc = cv2.VideoWriter_fourcc(*'DIVX')
out = cv2.VideoWriter('laneDetection.avi',fourcc, 30, (frame.shape[1],frame.shape[0]),1)

for j in video_list:
    out.write(j)
    
out.release()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-454e882f671d> in <module>()
#       2 out = cv2.VideoWriter('laneDetection.avi',fourcc, 30, (frame.shape[1],frame.shape[0]),1)
#       3
# ----> 4 for j in video_list:
#       5     out.write(j)
#       6
#
# NameError: name 'video_list' is not defined

# %%
import cv2
import numpy as np
from scipy import ndimage as ndi
from skimage.morphology import square,dilation
from skimage.io import imshow
import time
class HoughTransform:
    
    def __init__(self,filename = 'test.h264',threshold = 40):
        self.url = '../../video/' + filename
        self.cap = cv2.VideoCapture(self.url)
        self.countR = 0
        self.left = []
        self.right = []
        self.ret = 0
        self.frame = 0
        self.slope_right = 0
        self.slope_left = 0
        self.slope = 0
        self.slope_rightP = 0
        self.slope_leftP = 0
        self.font = cv2.FONT_HERSHEY_SIMPLEX
        self.threshold = threshold
        self.count = 0
        
    def _debug(self,debug = True):
        if (debug):            
#             cv2.putText(self.frame,str(self.slope_right),(100,25), self.font, 0.5,(255,255,255),2,cv2.LINE_AA)
            
            print('count :', self.count)
            print('slope_rightP :',self.slope_rightP)
            print('slope_leftP :',self.slope_leftP)
            print('slope_right :', self.slope_right)            
            print('slope_left :', self.slope_left)            
            print('slope :', self.slope)
            print()

    
    def region_of_interest(self,img, vertices):
        mask = np.zeros_like(img)
        match_mask_color = (255,)
        cv2.fillPoly(mask, vertices, 255)
        masked_image = cv2.bitwise_and(img, mask)
        return masked_image

    def findSlope(self,start,end,width):
        x1 = start[0]
        x2 = end[0]
        y1 = width-start[1]
        y2 = width-end[1]
        if (x2 - x1) != 0:
            m = (y2-y1)/(x2-x1)
            return m 
        
    def run(self,image=0,fromvideo = False,debugs = False):
        if(fromvideo):
            while self.cap.isOpened():
                self.ret, self.frame = self.cap.read()
                if not self.ret:
                    print("Can't receive frame (stream end?). Exiting ...")
                    break                
                if cv2.waitKey(1) == ord('q'):
                    break
                self.corerun()                    
                self._debug(debug = debugs)
            self.cap.release()
            cv2.destroyAllWindows()
        else:
            self.frame = image
            while cv2.waitKey(1) != ord('q'):                
                self.corerun()  
                self._debug(debug = debugs)
                return float(self.slope)
            self.cap.release()
            cv2.destroyAllWindows()
        
    def corerun(self):         
        self.frame = cv2.resize(self.frame,(100, 75))    
        height=self.frame.shape[0]
        width=self.frame.shape[1]
        region_of_interest_vertices = [   
            (0, height),
            (0, (height/3)+10),
            (width, (height/3)+10),
            (width, height)]
        
        gray=cv2.cvtColor(self.frame, cv2.COLOR_RGB2GRAY)

        edges = cv2.Canny(gray,100,200)
        edges = dilation(edges, square(3))
        # edges[:,width-3:width] = 0 
        # edges = ndi.gaussian_filter(edges,2)
        
        crop = self.region_of_interest(edges,np.array([region_of_interest_vertices], np.int32))
        self.frame=cv2.cvtColor(self.frame, cv2.COLOR_BGR2RGB)    
        lowerR=np.array([220,70,70])
        upperR=np.array([255,160,170])    
        maskR = cv2.inRange(self.frame, lowerR, upperR)
        
        for i in range(width):        
            if maskR[int(height/3)][i] == 255: 
                self.countR+=1
            if self.countR > 10:
                print('stop')
                break

        # Hough Transform
        lines = cv2.HoughLinesP(crop,rho = 1,theta = 1*np.pi/180,threshold = self.threshold,minLineLength = 10,maxLineGap = 250)
        font = cv2.FONT_HERSHEY_SIMPLEX
        l=[]
        r=[]

        # Draw lines on the image
        if(lines is not None) :
            for line in lines:  
                x1, y1, x2, y2 = line[0]
                if(self.findSlope((x1,y1),(x2,y2),width)):
                    if(x1 < int(width/2)):
                        l.append([x1,x2,y1,y2,self.findSlope((x1,y1),(x2,y2),width)])
                    else:
                        r.append([x1,x2,y1,y2,self.findSlope((x1,y1),(x2,y2),width)])

            l=np.array(l)
            r=np.array(r)
            self.slope_leftP = self.slope_left
            self.slope_rightP = self.slope_right
            # slope left
            if(len(l)):                
                self.slope_left = round(sum(l[:,4])/len(l),2)  
                x1 = round(sum(l[:,0])/len(l)).astype('int')
                x2 = round(sum(l[:,1])/len(l)).astype('int')
                y1 = round(sum(l[:,2])/len(l)).astype('int')
                y2 = round(sum(l[:,3])/len(l)).astype('int')
                cv2.line(self.frame, (x1, y1), (x2, y2), (255, 0, 0), 3)
            else:
                self.slope_left = self.slope_leftP

            # slope right
            if(len(r)):                
                self.slope_right = round(sum(r[:,4])/len(r),2)
                x1 = round(sum(r[:,0])/len(r)).astype('int')
                x2 = round(sum(r[:,1])/len(r)).astype('int')
                y1 = round(sum(r[:,2])/len(r)).astype('int')
                y2 = round(sum(r[:,3])/len(r)).astype('int')
                cv2.line(self.frame, (x1, y1), (x2, y2), (0, 0, 255), 3)
            else:
                self.slope_right = self.slope_rightP
            
            
        self.slope = round(self.slope_right + self.slope_left,3)
        if(self.slope > 2):
            self.slope = 2
        elif(self.slope < -2):
            self.slope = -2  
            
        self.frame=cv2.cvtColor(self.frame, cv2.COLOR_BGR2RGB)  
        cv2.putText(self.frame,str(self.count),(10,20), self.font, 0.5,(255,255,255),2,cv2.LINE_AA)
        self.count += 1
#         time.sleep(0.05)
        cv2.imshow('frame', self.frame)

# %%
image = cv2.imread('../dataset/original/300.jpg')
h = HoughTransform(threshold=10)
h.run(image,fromvideo=True,debugs=True)
# Out:
# count : 1
# slope_rightP : 0
# slope_leftP : 0
# slope_right : -2.01
# slope_left : 2.81
# slope : 0.8
#
# count : 2
# slope_rightP : -2.01
# slope_leftP : 2.81
# slope_right : -2.41
# slope_left : 2.36
# slope : -0.05
#
# count : 3
# slope_rightP : -2.41
# slope_leftP : 2.36
# slope_right : -2.03
# slope_left : 2.07
# slope : 0.04
#
# count : 4
# slope_rightP : -2.03
# slope_leftP : 2.07
# slope_right : -1.81
# slope_left : 2.16
# slope : 0.35
#
# count : 5
# slope_rightP : -1.81
# slope_leftP : 2.16
# slope_right : -1.74
# slope_left : 2.24
# slope : 0.5
#
# count : 6
# slope_rightP : -1.74
# slope_leftP : 2.24
# slope_right : -2.38
# slope_left : 0.3
# slope : -2
#
# count : 7
# slope_rightP : -2.38
# slope_leftP : 0.3
# slope_right : -1.78
# slope_left : 2.35
# slope : 0.57
#
# count : 8
# slope_rightP : -1.78
# slope_leftP : 2.35
# slope_right : -1.79
# slope_left : 2.21
# slope : 0.42
#
# count : 9
# slope_rightP : -1.79
# slope_leftP : 2.21
# slope_right : -2.04
# slope_left : 1.83
# slope : -0.21
#
# count : 10
# slope_rightP : -2.04
# slope_leftP : 1.83
# slope_right : -2.04
# slope_left : 1.88
# slope : -0.16
#
# count : 11
# slope_rightP : -2.04
# slope_leftP : 1.88
# slope_right : -2.22
# slope_left : 2.01
# slope : -0.21
#
# count : 12
# slope_rightP : -2.22
# slope_leftP : 2.01
# slope_right : -4.23
# slope_left : 1.88
# slope : -2
#
# count : 13
# slope_rightP : -4.23
# slope_leftP : 1.88
# slope_right : -1.92
# slope_left : 8.38
# slope : 2
#
# count : 14
# slope_rightP : -1.92
# slope_leftP : 8.38
# slope_right : -1.97
# slope_left : 4.85
# slope : 2
#
# count : 15
# slope_rightP : -1.97
# slope_leftP : 4.85
# slope_right : -3.05
# slope_left : 1.28
# slope : -1.77
#
# count : 16
# slope_rightP : -3.05
# slope_leftP : 1.28
# slope_right : -1.21
# slope_left : 2.2
# slope : 0.99
#
# count : 17
# slope_rightP : -1.21
# slope_leftP : 2.2
# slope_right : -1.93
# slope_left : 3.42
# slope : 1.49
#
# count : 18
# slope_rightP : -1.93
# slope_leftP : 3.42
# slope_right : -2.14
# slope_left : 1.77
# slope : -0.37
#
# count : 19
# slope_rightP : -2.14
# slope_leftP : 1.77
# slope_right : -4.23
# slope_left : 0.62
# slope : -2
#
# count : 20
# slope_rightP : -4.23
# slope_leftP : 0.62
# slope_right : -1.38
# slope_left : 2.09
# slope : 0.71
#
# count : 21
# slope_rightP : -1.38
# slope_leftP : 2.09
# slope_right : -2.01
# slope_left : 1.94
# slope : -0.07
#
# count : 22
# slope_rightP : -2.01
# slope_leftP : 1.94
# slope_right : -1.77
# slope_left : 1.31
# slope : -0.46
#
# count : 23
# slope_rightP : -1.77
# slope_leftP : 1.31
# slope_right : -1.66
# slope_left : 2.1
# slope : 0.44
#
# count : 24
# slope_rightP : -1.66
# slope_leftP : 2.1
# slope_right : -5.59
# slope_left : 1.82
# slope : -2
#
# count : 25
# slope_rightP : -5.59
# slope_leftP : 1.82
# slope_right : -2.25
# slope_left : 1.52
# slope : -0.73
#
# count : 26
# slope_rightP : -2.25
# slope_leftP : 1.52
# slope_right : 0.12
# slope_left : 2.41
# slope : 2
#
# count : 27
# slope_rightP : 0.12
# slope_leftP : 2.41
# slope_right : -2.68
# slope_left : 0.67
# slope : -2
#
# count : 28
# slope_rightP : -2.68
# slope_leftP : 0.67
# slope_right : -2.34
# slope_left : 1.66
# slope : -0.68
#
# count : 29
# slope_rightP : -2.34
# slope_leftP : 1.66
# slope_right : -1.63
# slope_left : 1.98
# slope : 0.35
#
# count : 30
# slope_rightP : -1.63
# slope_leftP : 1.98
# slope_right : -2.03
# slope_left : 1.5
# slope : -0.53
#
# count : 31
# slope_rightP : -2.03
# slope_leftP : 1.5
# slope_right : -2.97
# slope_left : 1.95
# slope : -1.02
#
# count : 32
# slope_rightP : -2.97
# slope_leftP : 1.95
# slope_right : -2.25
# slope_left : 2.52
# slope : 0.27
#
# count : 33
# slope_rightP : -2.25
# slope_leftP : 2.52
# slope_right : -1.67
# slope_left : 5.41
# slope : 2
#
# count : 34
# slope_rightP : -1.67
# slope_leftP : 5.41
# slope_right : -1.17
# slope_left : 1.95
# slope : 0.78
#
# count : 35
# slope_rightP : -1.17
# slope_leftP : 1.95
# slope_right : -1.91
# slope_left : 1.48
# slope : -0.43
#
# count : 36
# slope_rightP : -1.91
# slope_leftP : 1.48
# slope_right : -2.11
# slope_left : 2.98
# slope : 0.87
#
# count : 37
# slope_rightP : -2.11
# slope_leftP : 2.98
# slope_right : -1.68
# slope_left : 3.78
# slope : 2
#
# count : 38
# slope_rightP : -1.68
# slope_leftP : 3.78
# slope_right : -2.1
# slope_left : 1.72
# slope : -0.38
#
# count : 39
# slope_rightP : -2.1
# slope_leftP : 1.72
# slope_right : -2.31
# slope_left : 1.42
# slope : -0.89
#
# count : 40
# slope_rightP : -2.31
# slope_leftP : 1.42
# slope_right : -1.68
# slope_left : 1.31
# slope : -0.37
#
# count : 41
# slope_rightP : -1.68
# slope_leftP : 1.31
# slope_right : -1.87
# slope_left : 0.68
# slope : -1.19
#
# count : 42
# slope_rightP : -1.87
# slope_leftP : 0.68
# slope_right : -1.61
# slope_left : 4.8
# slope : 2
#
# count : 43
# slope_rightP : -1.61
# slope_leftP : 4.8
# slope_right : -1.74
# slope_left : 1.44
# slope : -0.3
#
# count : 44
# slope_rightP : -1.74
# slope_leftP : 1.44
# slope_right : -1.88
# slope_left : 1.35
# slope : -0.53
#
# count : 45
# slope_rightP : -1.88
# slope_leftP : 1.35
# slope_right : -2.31
# slope_left : 1.52
# slope : -0.79
#
# count : 46
# slope_rightP : -2.31
# slope_leftP : 1.52
# slope_right : -2.02
# slope_left : 1.95
# slope : -0.07
#
# count : 47
# slope_rightP : -2.02
# slope_leftP : 1.95
# slope_right : -1.84
# slope_left : 1.89
# slope : 0.05
#
# count : 48
# slope_rightP : -1.84
# slope_leftP : 1.89
# slope_right : -1.03
# slope_left : 1.73
# slope : 0.7
#
# count : 49
# slope_rightP : -1.03
# slope_leftP : 1.73
# slope_right : -1.93
# slope_left : 1.58
# slope : -0.35
#
# count : 50
# slope_rightP : -1.93
# slope_leftP : 1.58
# slope_right : -2.11
# slope_left : 1.61
# slope : -0.5
#
# count : 51
# slope_rightP : -2.11
# slope_leftP : 1.61
# slope_right : -2.48
# slope_left : 1.78
# slope : -0.7
#
# count : 52
# slope_rightP : -2.48
# slope_leftP : 1.78
# slope_right : -1.71
# slope_left : 1.86
# slope : 0.15
#
# count : 53
# slope_rightP : -1.71
# slope_leftP : 1.86
# slope_right : -1.76
# slope_left : 2.52
# slope : 0.76
#
# count : 54
# slope_rightP : -1.76
# slope_leftP : 2.52
# slope_right : -1.39
# slope_left : 2.08
# slope : 0.69
#
# count : 55
# slope_rightP : -1.39
# slope_leftP : 2.08
# slope_right : -1.46
# slope_left : 3.67
# slope : 2
#
# count : 56
# slope_rightP : -1.46
# slope_leftP : 3.67
# slope_right : -1.49
# slope_left : 2.3
# slope : 0.81
#
# count : 57
# slope_rightP : -1.49
# slope_leftP : 2.3
# slope_right : -3.69
# slope_left : 1.13
# slope : -2
#
# count : 58
# slope_rightP : -3.69
# slope_leftP : 1.13
# slope_right : -1.47
# slope_left : 2.91
# slope : 1.44
#
# count : 59
# slope_rightP : -1.47
# slope_leftP : 2.91
# slope_right : -1.28
# slope_left : 1.73
# slope : 0.45
#
# count : 60
# slope_rightP : -1.28
# slope_leftP : 1.73
# slope_right : -2.3
# slope_left : 3.96
# slope : 1.66
#
# count : 61
# slope_rightP : -2.3
# slope_leftP : 3.96
# slope_right : 0.45
# slope_left : 5.05
# slope : 2
#
# count : 62
# slope_rightP : 0.45
# slope_leftP : 5.05
# slope_right : -1.55
# slope_left : 2.07
# slope : 0.52
#
# count : 63
# slope_rightP : -1.55
# slope_leftP : 2.07
# slope_right : -2.16
# slope_left : 1.39
# slope : -0.77
#
# count : 64
# slope_rightP : -2.16
# slope_leftP : 1.39
# slope_right : -3.54
# slope_left : 1.53
# slope : -2
#
# count : 65
# slope_rightP : -3.54
# slope_leftP : 1.53
# slope_right : -2.79
# slope_left : 6.94
# slope : 2
#
# count : 66
# slope_rightP : -2.79
# slope_leftP : 6.94
# slope_right : -1.55
# slope_left : 1.77
# slope : 0.22
#
# count : 67
# slope_rightP : -1.55
# slope_leftP : 1.77
# slope_right : -2.01
# slope_left : 1.9
# slope : -0.11
#
# count : 68
# slope_rightP : -2.01
# slope_leftP : 1.9
# slope_right : 4.96
# slope_left : 1.79
# slope : 2
#
# count : 69
# slope_rightP : 4.96
# slope_leftP : 1.79
# slope_right : -1.62
# slope_left : 3.05
# slope : 1.43
#
# count : 70
# slope_rightP : -1.62
# slope_leftP : 3.05
# slope_right : -1.35
# slope_left : 2.31
# slope : 0.96
#
# count : 71
# slope_rightP : -1.35
# slope_leftP : 2.31
# slope_right : -1.15
# slope_left : 1.77
# slope : 0.62
#
# count : 72
# slope_rightP : -1.15
# slope_leftP : 1.77
# slope_right : -0.24
# slope_left : 2.0
# slope : 1.76
#
# count : 73
# slope_rightP : -0.24
# slope_leftP : 2.0
# slope_right : -1.83
# slope_left : 1.01
# slope : -0.82
#
# count : 74
# slope_rightP : -1.83
# slope_leftP : 1.01
# slope_right : -1.96
# slope_left : 1.24
# slope : -0.72
#
# count : 75
# slope_rightP : -1.96
# slope_leftP : 1.24
# slope_right : -1.42
# slope_left : 1.2
# slope : -0.22
#
# count : 76
# slope_rightP : -1.42
# slope_leftP : 1.2
# slope_right : -2.1
# slope_left : 1.08
# slope : -1.02
#
# count : 77
# slope_rightP : -2.1
# slope_leftP : 1.08
# slope_right : -0.4
# slope_left : 1.16
# slope : 0.76
#
# count : 78
# slope_rightP : -0.4
# slope_leftP : 1.16
# slope_right : -0.41
# slope_left : 2.57
# slope : 2
#
# count : 79
# slope_rightP : -0.41
# slope_leftP : 2.57
# slope_right : -1.41
# slope_left : 1.21
# slope : -0.2
#
# count : 80
# slope_rightP : -1.41
# slope_leftP : 1.21
# slope_right : 4.85
# slope_left : 1.0
# slope : 2
#
# count : 81
# slope_rightP : 4.85
# slope_leftP : 1.0
# slope_right : -2.28
# slope_left : 0.12
# slope : -2
#
# count : 82
# slope_rightP : -2.28
# slope_leftP : 0.12
# slope_right : -2.37
# slope_left : 3.18
# slope : 0.81
#
# count : 83
# slope_rightP : -2.37
# slope_leftP : 3.18
# slope_right : -1.49
# slope_left : -0.81
# slope : -2
#
# count : 84
# slope_rightP : -1.49
# slope_leftP : -0.81
# slope_right : -1.66
# slope_left : -1.2
# slope : -2
#
# count : 85
# slope_rightP : -1.66
# slope_leftP : -1.2
# slope_right : -4.66
# slope_left : 1.9
# slope : -2
#
# count : 86
# slope_rightP : -4.66
# slope_leftP : 1.9
# slope_right : -1.72
# slope_left : -0.72
# slope : -2
#
# count : 87
# slope_rightP : -1.72
# slope_leftP : -0.72
# slope_right : -1.31
# slope_left : 1.65
# slope : 0.34
#
# count : 88
# slope_rightP : -1.31
# slope_leftP : 1.65
# slope_right : -3.52
# slope_left : 2.21
# slope : -1.31
# count : 89
# slope_rightP : -3.52
# slope_leftP : 2.21
# slope_right : -1.81
# slope_left : 2.38
# slope : 0.57
#
# count : 90
# slope_rightP : -1.81
# slope_leftP : 2.38
# slope_right : -1.84
# slope_left : 2.29
# slope : 0.45
#
# count : 91
# slope_rightP : -1.84
# slope_leftP : 2.29
# slope_right : -1.46
# slope_left : 2.82
# slope : 1.36
#
# count : 92
# slope_rightP : -1.46
# slope_leftP : 2.82
# slope_right : -2.02
# slope_left : 2.1
# slope : 0.08
#
# count : 93
# slope_rightP : -2.02
# slope_leftP : 2.1
# slope_right : -1.35
# slope_left : 2.58
# slope : 1.23
#
# count : 94
# slope_rightP : -1.35
# slope_leftP : 2.58
# slope_right : -1.29
# slope_left : 1.54
# slope : 0.25
#
# count : 95
# slope_rightP : -1.29
# slope_leftP : 1.54
# slope_right : -2.07
# slope_left : 1.75
# slope : -0.32
#
# count : 96
# slope_rightP : -2.07
# slope_leftP : 1.75
# slope_right : -3.07
# slope_left : 2.07
# slope : -1.0
#
# count : 97
# slope_rightP : -3.07
# slope_leftP : 2.07
# slope_right : -2.23
# slope_left : 3.49
# slope : 1.26
#
# count : 98
# slope_rightP : -2.23
# slope_leftP : 3.49
# slope_right : -2.22
# slope_left : 2.37
# slope : 0.15
#
# count : 99
# slope_rightP : -2.22
# slope_leftP : 2.37
# slope_right : -0.95
# slope_left : 1.7
# slope : 0.75
#
# count : 100
# slope_rightP : -0.95
# slope_leftP : 1.7
# slope_right : -1.5
# slope_left : 2.39
# slope : 0.89
#
# count : 101
# slope_rightP : -1.5
# slope_leftP : 2.39
# slope_right : -1.87
# slope_left : 1.19
# slope : -0.68
#
# count : 102
# slope_rightP : -1.87
# slope_leftP : 1.19
# slope_right : -2.14
# slope_left : 1.65
# slope : -0.49
#
# count : 103
# slope_rightP : -2.14
# slope_leftP : 1.65
# slope_right : -1.46
# slope_left : 2.61
# slope : 1.15
#
# count : 104
# slope_rightP : -1.46
# slope_leftP : 2.61
# slope_right : -2.3
# slope_left : 1.72
# slope : -0.58
#
# count : 105
# slope_rightP : -2.3
# slope_leftP : 1.72
# slope_right : -1.06
# slope_left : 4.9
# slope : 2
#
# count : 106
# slope_rightP : -1.06
# slope_leftP : 4.9
# slope_right : -1.72
# slope_left : 2.77
# slope : 1.05
#
# count : 107
# slope_rightP : -1.72
# slope_leftP : 2.77
# slope_right : 0.22
# slope_left : 2.96
# slope : 2
#
# count : 108
# slope_rightP : 0.22
# slope_leftP : 2.96
# slope_right : -2.99
# slope_left : 2.22
# slope : -0.77
#
# count : 109
# slope_rightP : -2.99
# slope_leftP : 2.22
# slope_right : -2.59
# slope_left : 1.94
# slope : -0.65
#
# count : 110
# slope_rightP : -2.59
# slope_leftP : 1.94
# slope_right : -2.22
# slope_left : 2.62
# slope : 0.4
#
# count : 111
# slope_rightP : -2.22
# slope_leftP : 2.62
# slope_right : -2.09
# slope_left : 0.24
# slope : -1.85
#
# count : 112
# slope_rightP : -2.09
# slope_leftP : 0.24
# slope_right : -2.3
# slope_left : 1.77
# slope : -0.53
#
# count : 113
# slope_rightP : -2.3
# slope_leftP : 1.77
# slope_right : -2.49
# slope_left : 5.25
# slope : 2
#
# count : 114
# slope_rightP : -2.49
# slope_leftP : 5.25
# slope_right : -2.54
# slope_left : 1.57
# slope : -0.97
#
# count : 115
# slope_rightP : -2.54
# slope_leftP : 1.57
# slope_right : -2.4
# slope_left : -2.92
# slope : -2
#
# count : 116
# slope_rightP : -2.4
# slope_leftP : -2.92
# slope_right : -2.39
# slope_left : 1.06
# slope : -1.33
#
# count : 117
# slope_rightP : -2.39
# slope_leftP : 1.06
# slope_right : -2.44
# slope_left : 3.7
# slope : 1.26
#
# count : 118
# slope_rightP : -2.44
# slope_leftP : 3.7
# slope_right : -2.71
# slope_left : 2.22
# slope : -0.49
#
# count : 119
# slope_rightP : -2.71
# slope_leftP : 2.22
# slope_right : -2.73
# slope_left : 1.01
# slope : -1.72
#
# count : 120
# slope_rightP : -2.73
# slope_leftP : 1.01
# slope_right : -2.74
# slope_left : 1.92
# slope : -0.82
#
# count : 121
# slope_rightP : -2.74
# slope_leftP : 1.92
# slope_right : -2.59
# slope_left : 1.87
# slope : -0.72
#
# count : 122
# slope_rightP : -2.59
# slope_leftP : 1.87
# slope_right : -4.04
# slope_left : 1.73
# slope : -2
#
# count : 123
# slope_rightP : -4.04
# slope_leftP : 1.73
# slope_right : 0.93
# slope_left : -0.44
# slope : 0.49
#
# count : 124
# slope_rightP : 0.93
# slope_leftP : -0.44
# slope_right : -4.53
# slope_left : 1.39
# slope : -2
#
# count : 125
# slope_rightP : -4.53
# slope_leftP : 1.39
# slope_right : -2.63
# slope_left : 0.3
# slope : -2
#
# count : 126
# slope_rightP : -2.63
# slope_leftP : 0.3
# slope_right : 6.38
# slope_left : 2.45
# slope : 2
#
# count : 127
# slope_rightP : 6.38
# slope_leftP : 2.45
# slope_right : -0.27
# slope_left : 2.06
# slope : 1.79
#
# count : 128
# slope_rightP : -0.27
# slope_leftP : 2.06
# slope_right : -3.8
# slope_left : 1.71
# slope : -2
#
# count : 129
# slope_rightP : -3.8
# slope_leftP : 1.71
# slope_right : 1.2
# slope_left : 2.16
# slope : 2
#
# count : 130
# slope_rightP : 1.2
# slope_leftP : 2.16
# slope_right : 2.12
# slope_left : 2.02
# slope : 2
#
# count : 131
# slope_rightP : 2.12
# slope_leftP : 2.02
# slope_right : -0.23
# slope_left : 2.0
# slope : 1.77
#
# count : 132
# slope_rightP : -0.23
# slope_leftP : 2.0
# slope_right : -11.5
# slope_left : 2.12
# slope : -2
#
# count : 133
# slope_rightP : -11.5
# slope_leftP : 2.12
# slope_right : 14.52
# slope_left : 3.29
# slope : 2
#
# count : 134
# slope_rightP : 14.52
# slope_leftP : 3.29
# slope_right : 5.74
# slope_left : 2.39
# slope : 2
#
# count : 135
# slope_rightP : 5.74
# slope_leftP : 2.39
# slope_right : 11.3
# slope_left : 2.32
# slope : 2
#
# count : 136
# slope_rightP : 11.3
# slope_leftP : 2.32
# slope_right : -14.76
# slope_left : 2.66
# slope : -2
#
# count : 137
# slope_rightP : -14.76
# slope_leftP : 2.66
# slope_right : -10.75
# slope_left : 2.83
# slope : -2
#
# count : 138
# slope_rightP : -10.75
# slope_leftP : 2.83
# slope_right : -1.57
# slope_left : 1.97
# slope : 0.4
#
# count : 139
# slope_rightP : -1.57
# slope_leftP : 1.97
# slope_right : -4.83
# slope_left : 2.39
# slope : -2
#
# count : 140
# slope_rightP : -4.83
# slope_leftP : 2.39
# slope_right : -9.0
# slope_left : 2.36
# slope : -2
#
# count : 141
# slope_rightP : -9.0
# slope_leftP : 2.36
# slope_right : 8.5
# slope_left : 1.65
# slope : 2
#
# count : 142
# slope_rightP : 8.5
# slope_leftP : 1.65
# slope_right : 8.5
# slope_left : 2.24
# slope : 2
#
# count : 143
# slope_rightP : 8.5
# slope_leftP : 2.24
# slope_right : 8.5
# slope_left : 1.88
# slope : 2
#
# count : 144
# slope_rightP : 8.5
# slope_leftP : 1.88
# slope_right : 8.5
# slope_left : 1.45
# slope : 2
#
# count : 145
# slope_rightP : 8.5
# slope_leftP : 1.45
# slope_right : 8.5
# slope_left : 2.03
# slope : 2
#
# count : 146
# slope_rightP : 8.5
# slope_leftP : 2.03
# slope_right : 8.5
# slope_left : 1.58
# slope : 2
#
# count : 147
# slope_rightP : 8.5
# slope_leftP : 1.58
# slope_right : 8.5
# slope_left : 1.46
# slope : 2
#
# count : 148
# slope_rightP : 8.5
# slope_leftP : 1.46
# slope_right : 8.5
# slope_left : 1.88
# slope : 2
#
# count : 149
# slope_rightP : 8.5
# slope_leftP : 1.88
# slope_right : 8.5
# slope_left : 1.35
# slope : 2
#
# count : 150
# slope_rightP : 8.5
# slope_leftP : 1.35
# slope_right : 8.5
# slope_left : 1.14
# slope : 2
#
# count : 151
# slope_rightP : 8.5
# slope_leftP : 1.14
# slope_right : 8.5
# slope_left : 1.66
# slope : 2
#
# count : 152
# slope_rightP : 8.5
# slope_leftP : 1.66
# slope_right : 8.5
# slope_left : 1.38
# slope : 2
#
# count : 153
# slope_rightP : 8.5
# slope_leftP : 1.38
# slope_right : 8.5
# slope_left : 1.32
# slope : 2
#
# count : 154
# slope_rightP : 8.5
# slope_leftP : 1.32
# slope_right : 8.5
# slope_left : 1.46
# slope : 2
#
# count : 155
# slope_rightP : 8.5
# slope_leftP : 1.46
# slope_right : 8.5
# slope_left : 0.97
# slope : 2
#
# count : 156
# slope_rightP : 8.5
# slope_leftP : 0.97
# slope_right : 8.5
# slope_left : 1.35
# slope : 2
#
# count : 157
# slope_rightP : 8.5
# slope_leftP : 1.35
# slope_right : 8.5
# slope_left : 1.01
# slope : 2
#
# count : 158
# slope_rightP : 8.5
# slope_leftP : 1.01
# slope_right : 8.5
# slope_left : 0.99
# slope : 2
#
# count : 159
# slope_rightP : 8.5
# slope_leftP : 0.99
# slope_right : 8.5
# slope_left : 0.91
# slope : 2
#
# count : 160
# slope_rightP : 8.5
# slope_leftP : 0.91
# slope_right : 8.5
# slope_left : 1.04
# slope : 2
#
# count : 161
# slope_rightP : 8.5
# slope_leftP : 1.04
# slope_right : 8.5
# slope_left : 0.7
# slope : 2
#
# count : 162
# slope_rightP : 8.5
# slope_leftP : 0.7
# slope_right : 8.5
# slope_left : 0.9
# slope : 2
#
# count : 163
# slope_rightP : 8.5
# slope_leftP : 0.9
# slope_right : 8.5
# slope_left : 1.03
# slope : 2
#
# count : 164
# slope_rightP : 8.5
# slope_leftP : 1.03
# slope_right : 8.5
# slope_left : 0.66
# slope : 2
#
# count : 165
# slope_rightP : 8.5
# slope_leftP : 0.66
# slope_right : 8.5
# slope_left : 0.86
# slope : 2
#
# count : 166
# slope_rightP : 8.5
# slope_leftP : 0.86
# slope_right : 8.5
# slope_left : -0.35
# slope : 2
#
# count : 167
# slope_rightP : 8.5
# slope_leftP : -0.35
# slope_right : 8.5
# slope_left : 0.7
# slope : 2
#
# count : 168
# slope_rightP : 8.5
# slope_leftP : 0.7
# slope_right : 8.5
# slope_left : 0.75
# slope : 2
#
# count : 169
# slope_rightP : 8.5
# slope_leftP : 0.75
# slope_right : 8.5
# slope_left : 0.59
# slope : 2
#
# count : 170
# slope_rightP : 8.5
# slope_leftP : 0.59
# slope_right : 8.5
# slope_left : 0.7
# slope : 2
#
# count : 171
# slope_rightP : 8.5
# slope_leftP : 0.7
# slope_right : 8.5
# slope_left : -3.05
# slope : 2
#
# count : 172
# slope_rightP : 8.5
# slope_leftP : -3.05
# slope_right : 8.5
# slope_left : 0.49
# slope : 2
#
# count : 173
# slope_rightP : 8.5
# slope_leftP : 0.49
# slope_right : 8.5
# slope_left : 0.7
# slope : 2
#
# count : 174
# slope_rightP : 8.5
# slope_leftP : 0.7
# slope_right : 8.5
# slope_left : 0.77
# slope : 2
#
# count : 175
# slope_rightP : 8.5
# slope_leftP : 0.77
# slope_right : 8.5
# slope_left : 0.55
# slope : 2
#
# count : 176
# slope_rightP : 8.5
# slope_leftP : 0.55
# slope_right : 8.5
# slope_left : 0.81
# slope : 2
#
# count : 177
# slope_rightP : 8.5
# slope_leftP : 0.81
# slope_right : 8.5
# slope_left : -0.15
# slope : 2
#
# count : 178
# slope_rightP : 8.5
# slope_leftP : -0.15
# slope_right : 4.5
# slope_left : 2.62
# slope : 2
#
# count : 179
# slope_rightP : 4.5
# slope_leftP : 2.62
# slope_right : -7.92
# slope_left : 0.74
# slope : -2
#
# count : 180
# slope_rightP : -7.92
# slope_leftP : 0.74
# slope_right : -9.27
# slope_left : 1.21
# slope : -2
# count : 181
# slope_rightP : -9.27
# slope_leftP : 1.21
# slope_right : -16.75
# slope_left : 1.06
# slope : -2
#
# count : 182
# slope_rightP : -16.75
# slope_leftP : 1.06
# slope_right : -5.59
# slope_left : 0.91
# slope : -2
#
# count : 183
# slope_rightP : -5.59
# slope_leftP : 0.91
# slope_right : -4.78
# slope_left : 0.93
# slope : -2
#
# count : 184
# slope_rightP : -4.78
# slope_leftP : 0.93
# slope_right : -4.8
# slope_left : 1.07
# slope : -2
#
# count : 185
# slope_rightP : -4.8
# slope_leftP : 1.07
# slope_right : -3.92
# slope_left : 0.97
# slope : -2
#
# count : 186
# slope_rightP : -3.92
# slope_leftP : 0.97
# slope_right : -6.36
# slope_left : 1.03
# slope : -2
#
# count : 187
# slope_rightP : -6.36
# slope_leftP : 1.03
# slope_right : -4.29
# slope_left : 1.31
# slope : -2
#
# count : 188
# slope_rightP : -4.29
# slope_leftP : 1.31
# slope_right : -4.44
# slope_left : 1.62
# slope : -2
#
# count : 189
# slope_rightP : -4.44
# slope_leftP : 1.62
# slope_right : -7.71
# slope_left : 1.2
# slope : -2
#
# count : 190
# slope_rightP : -7.71
# slope_leftP : 1.2
# slope_right : -3.48
# slope_left : 1.28
# slope : -2
#
# count : 191
# slope_rightP : -3.48
# slope_leftP : 1.28
# slope_right : -2.91
# slope_left : 1.3
# slope : -1.61
#
# count : 192
# slope_rightP : -2.91
# slope_leftP : 1.3
# slope_right : -3.02
# slope_left : 2.13
# slope : -0.89
#
# count : 193
# slope_rightP : -3.02
# slope_leftP : 2.13
# slope_right : -3.4
# slope_left : 1.62
# slope : -1.78
#
# count : 194
# slope_rightP : -3.4
# slope_leftP : 1.62
# slope_right : -4.76
# slope_left : 1.32
# slope : -2
#
# count : 195
# slope_rightP : -4.76
# slope_leftP : 1.32
# slope_right : -2.76
# slope_left : 2.26
# slope : -0.5
#
# count : 196
# slope_rightP : -2.76
# slope_leftP : 2.26
# slope_right : -4.75
# slope_left : 1.31
# slope : -2
#
# count : 197
# slope_rightP : -4.75
# slope_leftP : 1.31
# slope_right : -1.87
# slope_left : 1.34
# slope : -0.53
#
# count : 198
# slope_rightP : -1.87
# slope_leftP : 1.34
# slope_right : -2.03
# slope_left : 1.2
# slope : -0.83
#
# count : 199
# slope_rightP : -2.03
# slope_leftP : 1.2
# slope_right : -2.91
# slope_left : 2.27
# slope : -0.64
#
# count : 200
# slope_rightP : -2.91
# slope_leftP : 2.27
# slope_right : -1.58
# slope_left : 2.17
# slope : 0.59
#
# count : 201
# slope_rightP : -1.58
# slope_leftP : 2.17
# slope_right : -2.86
# slope_left : 2.21
# slope : -0.65
#
# count : 202
# slope_rightP : -2.86
# slope_leftP : 2.21
# slope_right : -2.55
# slope_left : 2.4
# slope : -0.15
#
# count : 203
# slope_rightP : -2.55
# slope_leftP : 2.4
# slope_right : -0.13
# slope_left : 1.7
# slope : 1.57
#
# count : 204
# slope_rightP : -0.13
# slope_leftP : 1.7
# slope_right : -3.0
# slope_left : 1.53
# slope : -1.47
#
# count : 205
# slope_rightP : -3.0
# slope_leftP : 1.53
# slope_right : -3.54
# slope_left : 1.34
# slope : -2
#
# count : 206
# slope_rightP : -3.54
# slope_leftP : 1.34
# slope_right : -2.93
# slope_left : 1.48
# slope : -1.45
#
# count : 207
# slope_rightP : -2.93
# slope_leftP : 1.48
# slope_right : -2.33
# slope_left : 1.79
# slope : -0.54
#
# count : 208
# slope_rightP : -2.33
# slope_leftP : 1.79
# slope_right : -2.28
# slope_left : 5.8
# slope : 2
#
# count : 209
# slope_rightP : -2.28
# slope_leftP : 5.8
# slope_right : -3.38
# slope_left : 1.02
# slope : -2
#
# count : 210
# slope_rightP : -3.38
# slope_leftP : 1.02
# slope_right : -2.44
# slope_left : 2.6
# slope : 0.16
#
# count : 211
# slope_rightP : -2.44
# slope_leftP : 2.6
# slope_right : -1.71
# slope_left : 0.88
# slope : -0.83
#
# count : 212
# slope_rightP : -1.71
# slope_leftP : 0.88
# slope_right : -1.46
# slope_left : 1.76
# slope : 0.3
#
# count : 213
# slope_rightP : -1.46
# slope_leftP : 1.76
# slope_right : -2.93
# slope_left : 1.62
# slope : -1.31
#
# count : 214
# slope_rightP : -2.93
# slope_leftP : 1.62
# slope_right : -1.62
# slope_left : 1.82
# slope : 0.2
#
# count : 215
# slope_rightP : -1.62
# slope_leftP : 1.82
# slope_right : -2.38
# slope_left : 1.91
# slope : -0.47
#
# count : 216
# slope_rightP : -2.38
# slope_leftP : 1.91
# slope_right : -2.82
# slope_left : 2.72
# slope : -0.1
#
# count : 217
# slope_rightP : -2.82
# slope_leftP : 2.72
# slope_right : -3.14
# slope_left : -0.62
# slope : -2
#
# count : 218
# slope_rightP : -3.14
# slope_leftP : -0.62
# slope_right : -2.47
# slope_left : 2.69
# slope : 0.22
#
# count : 219
# slope_rightP : -2.47
# slope_leftP : 2.69
# slope_right : -1.25
# slope_left : 2.18
# slope : 0.93
#
# count : 220
# slope_rightP : -1.25
# slope_leftP : 2.18
# slope_right : -2.44
# slope_left : 2.19
# slope : -0.25
#
# count : 221
# slope_rightP : -2.44
# slope_leftP : 2.19
# slope_right : 2.3
# slope_left : 1.99
# slope : 2
#
# count : 222
# slope_rightP : 2.3
# slope_leftP : 1.99
# slope_right : -1.11
# slope_left : -0.62
# slope : -1.73
#
# count : 223
# slope_rightP : -1.11
# slope_leftP : -0.62
# slope_right : -1.7
# slope_left : 1.59
# slope : -0.11
#
# count : 224
# slope_rightP : -1.7
# slope_leftP : 1.59
# slope_right : -1.86
# slope_left : 2.01
# slope : 0.15
#
# count : 225
# slope_rightP : -1.86
# slope_leftP : 2.01
# slope_right : -2.05
# slope_left : 2.33
# slope : 0.28
#
# count : 226
# slope_rightP : -2.05
# slope_leftP : 2.33
# slope_right : 0.11
# slope_left : 2.23
# slope : 2
#
# count : 227
# slope_rightP : 0.11
# slope_leftP : 2.23
# slope_right : -2.13
# slope_left : 3.19
# slope : 1.06
#
# count : 228
# slope_rightP : -2.13
# slope_leftP : 3.19
# slope_right : -1.49
# slope_left : 4.33
# slope : 2
#
# count : 229
# slope_rightP : -1.49
# slope_leftP : 4.33
# slope_right : -1.76
# slope_left : 1.75
# slope : -0.01
#
# count : 230
# slope_rightP : -1.76
# slope_leftP : 1.75
# slope_right : -1.02
# slope_left : 2.19
# slope : 1.17
#
# count : 231
# slope_rightP : -1.02
# slope_leftP : 2.19
# slope_right : -1.96
# slope_left : 2.19
# slope : 0.23
#
# count : 232
# slope_rightP : -1.96
# slope_leftP : 2.19
# slope_right : -2.78
# slope_left : 2.48
# slope : -0.3
#
# count : 233
# slope_rightP : -2.78
# slope_leftP : 2.48
# slope_right : -2.04
# slope_left : 2.64
# slope : 0.6
#
# count : 234
# slope_rightP : -2.04
# slope_leftP : 2.64
# slope_right : -2.33
# slope_left : 2.8
# slope : 0.47
#
# count : 235
# slope_rightP : -2.33
# slope_leftP : 2.8
# slope_right : -1.75
# slope_left : 2.5
# slope : 0.75
#
# count : 236
# slope_rightP : -1.75
# slope_leftP : 2.5
# slope_right : -2.47
# slope_left : 1.69
# slope : -0.78
#
# count : 237
# slope_rightP : -2.47
# slope_leftP : 1.69
# slope_right : -3.46
# slope_left : 1.96
# slope : -1.5
#
# count : 238
# slope_rightP : -3.46
# slope_leftP : 1.96
# slope_right : -2.37
# slope_left : 1.56
# slope : -0.81
#
# count : 239
# slope_rightP : -2.37
# slope_leftP : 1.56
# slope_right : -2.46
# slope_left : 2.03
# slope : -0.43
#
# count : 240
# slope_rightP : -2.46
# slope_leftP : 2.03
# slope_right : -2.04
# slope_left : 2.18
# slope : 0.14
#
# count : 241
# slope_rightP : -2.04
# slope_leftP : 2.18
# slope_right : -2.19
# slope_left : 2.82
# slope : 0.63
#
# count : 242
# slope_rightP : -2.19
# slope_leftP : 2.82
# slope_right : -2.16
# slope_left : 3.57
# slope : 1.41
#
# count : 243
# slope_rightP : -2.16
# slope_leftP : 3.57
# slope_right : -2.22
# slope_left : 4.75
# slope : 2
#
# count : 244
# slope_rightP : -2.22
# slope_leftP : 4.75
# slope_right : -2.31
# slope_left : 2.23
# slope : -0.08
#
# count : 245
# slope_rightP : -2.31
# slope_leftP : 2.23
# slope_right : -2.32
# slope_left : 2.56
# slope : 0.24
#
# count : 246
# slope_rightP : -2.32
# slope_leftP : 2.56
# slope_right : -1.53
# slope_left : 1.32
# slope : -0.21
#
# count : 247
# slope_rightP : -1.53
# slope_leftP : 1.32
# slope_right : -1.41
# slope_left : 2.55
# slope : 1.14
#
# count : 248
# slope_rightP : -1.41
# slope_leftP : 2.55
# slope_right : -1.77
# slope_left : 2.18
# slope : 0.41
#
# count : 249
# slope_rightP : -1.77
# slope_leftP : 2.18
# slope_right : -1.86
# slope_left : 5.58
# slope : 2
#
# count : 250
# slope_rightP : -1.86
# slope_leftP : 5.58
# slope_right : -2.54
# slope_left : 8.16
# slope : 2
#
# count : 251
# slope_rightP : -2.54
# slope_leftP : 8.16
# slope_right : -1.77
# slope_left : 3.42
# slope : 1.65
#
# count : 252
# slope_rightP : -1.77
# slope_leftP : 3.42
# slope_right : -2.29
# slope_left : 7.35
# slope : 2
#
# count : 253
# slope_rightP : -2.29
# slope_leftP : 7.35
# slope_right : -2.26
# slope_left : 1.43
# slope : -0.83
#
# count : 254
# slope_rightP : -2.26
# slope_leftP : 1.43
# slope_right : -2.2
# slope_left : 2.41
# slope : 0.21
#
# count : 255
# slope_rightP : -2.2
# slope_leftP : 2.41
# slope_right : -1.75
# slope_left : 2.43
# slope : 0.68
#
# count : 256
# slope_rightP : -1.75
# slope_leftP : 2.43
# slope_right : -2.3
# slope_left : 4.45
# slope : 2
#
# count : 257
# slope_rightP : -2.3
# slope_leftP : 4.45
# slope_right : -1.85
# slope_left : 3.39
# slope : 1.54
#
# count : 258
# slope_rightP : -1.85
# slope_leftP : 3.39
# slope_right : -2.09
# slope_left : 4.26
# slope : 2
#
# count : 259
# slope_rightP : -2.09
# slope_leftP : 4.26
# slope_right : -2.11
# slope_left : 2.4
# slope : 0.29
#
# count : 260
# slope_rightP : -2.11
# slope_leftP : 2.4
# slope_right : -2.05
# slope_left : 2.49
# slope : 0.44
#
# count : 261
# slope_rightP : -2.05
# slope_leftP : 2.49
# slope_right : -2.17
# slope_left : 2.51
# slope : 0.34
#
# count : 262
# slope_rightP : -2.17
# slope_leftP : 2.51
# slope_right : -2.05
# slope_left : 3.99
# slope : 1.94
#
# count : 263
# slope_rightP : -2.05
# slope_leftP : 3.99
# slope_right : -2.16
# slope_left : 2.07
# slope : -0.09
#
# count : 264
# slope_rightP : -2.16
# slope_leftP : 2.07
# slope_right : -1.83
# slope_left : 2.32
# slope : 0.49
#
# count : 265
# slope_rightP : -1.83
# slope_leftP : 2.32
# slope_right : -1.76
# slope_left : 1.49
# slope : -0.27
#
# count : 266
# slope_rightP : -1.76
# slope_leftP : 1.49
# slope_right : -2.44
# slope_left : 6.05
# slope : 2
#
# count : 267
# slope_rightP : -2.44
# slope_leftP : 6.05
# slope_right : -2.15
# slope_left : 1.99
# slope : -0.16
#
# count : 268
# slope_rightP : -2.15
# slope_leftP : 1.99
# slope_right : -2.46
# slope_left : 3.55
# slope : 1.09
#
# count : 269
# slope_rightP : -2.46
# slope_leftP : 3.55
# slope_right : -1.98
# slope_left : -0.86
# slope : -2
#
# count : 270
# slope_rightP : -1.98
# slope_leftP : -0.86
# slope_right : -2.11
# slope_left : 3.05
# slope : 0.94
# count : 271
# slope_rightP : -2.11
# slope_leftP : 3.05
# slope_right : -1.96
# slope_left : 1.84
# slope : -0.12
#
# count : 272
# slope_rightP : -1.96
# slope_leftP : 1.84
# slope_right : -2.02
# slope_left : 2.34
# slope : 0.32
#
# count : 273
# slope_rightP : -2.02
# slope_leftP : 2.34
# slope_right : -2.69
# slope_left : 2.51
# slope : -0.18
#
# count : 274
# slope_rightP : -2.69
# slope_leftP : 2.51
# slope_right : -1.94
# slope_left : 8.45
# slope : 2
#
# count : 275
# slope_rightP : -1.94
# slope_leftP : 8.45
# slope_right : -1.89
# slope_left : 4.25
# slope : 2
#
# count : 276
# slope_rightP : -1.89
# slope_leftP : 4.25
# slope_right : -1.74
# slope_left : 5.0
# slope : 2
#
# count : 277
# slope_rightP : -1.74
# slope_leftP : 5.0
# slope_right : -1.83
# slope_left : 2.82
# slope : 0.99
#
# count : 278
# slope_rightP : -1.83
# slope_leftP : 2.82
# slope_right : -2.05
# slope_left : 1.24
# slope : -0.81
#
# count : 279
# slope_rightP : -2.05
# slope_leftP : 1.24
# slope_right : -3.09
# slope_left : 1.92
# slope : -1.17
#
# count : 280
# slope_rightP : -3.09
# slope_leftP : 1.92
# slope_right : -3.01
# slope_left : 1.9
# slope : -1.11
#
# count : 281
# slope_rightP : -3.01
# slope_leftP : 1.9
# slope_right : -2.45
# slope_left : -0.0
# slope : -2
#
# count : 282
# slope_rightP : -2.45
# slope_leftP : -0.0
# slope_right : -3.36
# slope_left : 0.89
# slope : -2
#
# count : 283
# slope_rightP : -3.36
# slope_leftP : 0.89
# slope_right : -4.45
# slope_left : 1.58
# slope : -2
#
# count : 284
# slope_rightP : -4.45
# slope_leftP : 1.58
# slope_right : -1.69
# slope_left : 3.46
# slope : 1.77
#
# count : 285
# slope_rightP : -1.69
# slope_leftP : 3.46
# slope_right : -0.72
# slope_left : 1.28
# slope : 0.56
#
# count : 286
# slope_rightP : -0.72
# slope_leftP : 1.28
# slope_right : 12.66
# slope_left : 2.33
# slope : 2
#
# count : 287
# slope_rightP : 12.66
# slope_leftP : 2.33
# slope_right : -3.06
# slope_left : 2.45
# slope : -0.61
#
# count : 288
# slope_rightP : -3.06
# slope_leftP : 2.45
# slope_right : -3.95
# slope_left : 3.83
# slope : -0.12
#
# count : 289
# slope_rightP : -3.95
# slope_leftP : 3.83
# slope_right : -2.03
# slope_left : 3.47
# slope : 1.44
#
# count : 290
# slope_rightP : -2.03
# slope_leftP : 3.47
# slope_right : 4.26
# slope_left : 5.2
# slope : 2
#
# count : 291
# slope_rightP : 4.26
# slope_leftP : 5.2
# slope_right : -0.14
# slope_left : 1.55
# slope : 1.41
#
# count : 292
# slope_rightP : -0.14
# slope_leftP : 1.55
# slope_right : -7.4
# slope_left : 1.68
# slope : -2
#
# count : 293
# slope_rightP : -7.4
# slope_leftP : 1.68
# slope_right : 10.61
# slope_left : 2.66
# slope : 2
#
# count : 294
# slope_rightP : 10.61
# slope_leftP : 2.66
# slope_right : -0.11
# slope_left : 7.34
# slope : 2
#
# count : 295
# slope_rightP : -0.11
# slope_leftP : 7.34
# slope_right : 3.02
# slope_left : 1.58
# slope : 2
#
# count : 296
# slope_rightP : 3.02
# slope_leftP : 1.58
# slope_right : 0.5
# slope_left : -1.98
# slope : -1.48
#
# count : 297
# slope_rightP : 0.5
# slope_leftP : -1.98
# slope_right : 14.5
# slope_left : 1.98
# slope : 2
#
# count : 298
# slope_rightP : 14.5
# slope_leftP : 1.98
# slope_right : 0.0
# slope_left : -0.28
# slope : -0.28
#
# count : 299
# slope_rightP : 0.0
# slope_leftP : -0.28
# slope_right : 14.75
# slope_left : 1.71
# slope : 2
#
# count : 300
# slope_rightP : 14.75
# slope_leftP : 1.71
# slope_right : 5.11
# slope_left : 2.67
# slope : 2
#
# count : 301
# slope_rightP : 5.11
# slope_leftP : 2.67
# slope_right : 17.0
# slope_left : 3.4
# slope : 2
#
# count : 302
# slope_rightP : 17.0
# slope_leftP : 3.4
# slope_right : 2.5
# slope_left : 2.23
# slope : 2
#
# count : 303
# slope_rightP : 2.5
# slope_leftP : 2.23
# slope_right : 2.5
# slope_left : 1.27
# slope : 2
#
# count : 304
# slope_rightP : 2.5
# slope_leftP : 1.27
# slope_right : 0.5
# slope_left : 1.45
# slope : 1.95
#
# count : 305
# slope_rightP : 0.5
# slope_leftP : 1.45
# slope_right : -12.33
# slope_left : 1.45
# slope : -2
#
# count : 306
# slope_rightP : -12.33
# slope_leftP : 1.45
# slope_right : 4.83
# slope_left : -0.31
# slope : 2
#
# count : 307
# slope_rightP : 4.83
# slope_leftP : -0.31
# slope_right : 4.83
# slope_left : 0.8
# slope : 2
#
# count : 308
# slope_rightP : 4.83
# slope_leftP : 0.8
# slope_right : -13.0
# slope_left : 1.03
# slope : -2
#
# count : 309
# slope_rightP : -13.0
# slope_leftP : 1.03
# slope_right : 6.78
# slope_left : -0.47
# slope : 2
#
# count : 310
# slope_rightP : 6.78
# slope_leftP : -0.47
# slope_right : -2.75
# slope_left : 1.02
# slope : -1.73
#
# count : 311
# slope_rightP : -2.75
# slope_leftP : 1.02
# slope_right : 4.21
# slope_left : 1.09
# slope : 2
#
# count : 312
# slope_rightP : 4.21
# slope_leftP : 1.09
# slope_right : 3.29
# slope_left : 0.85
# slope : 2
#
# count : 313
# slope_rightP : 3.29
# slope_leftP : 0.85
# slope_right : 3.29
# slope_left : 0.78
# slope : 2
#
# count : 314
# slope_rightP : 3.29
# slope_leftP : 0.78
# slope_right : 4.0
# slope_left : 1.05
# slope : 2
#
# count : 315
# slope_rightP : 4.0
# slope_leftP : 1.05
# slope_right : 4.0
# slope_left : 2.16
# slope : 2
#
# count : 316
# slope_rightP : 4.0
# slope_leftP : 2.16
# slope_right : 4.0
# slope_left : 0.68
# slope : 2
#
# count : 317
# slope_rightP : 4.0
# slope_leftP : 0.68
# slope_right : 4.0
# slope_left : 0.78
# slope : 2
#
# count : 318
# slope_rightP : 4.0
# slope_leftP : 0.78
# slope_right : 4.0
# slope_left : 0.78
# slope : 2
#
# count : 319
# slope_rightP : 4.0
# slope_leftP : 0.78
# slope_right : 4.0
# slope_left : 0.72
# slope : 2
#
# count : 320
# slope_rightP : 4.0
# slope_leftP : 0.72
# slope_right : 4.0
# slope_left : 0.78
# slope : 2
#
# count : 321
# slope_rightP : 4.0
# slope_leftP : 0.78
# slope_right : 4.0
# slope_left : 0.74
# slope : 2
#
# count : 322
# slope_rightP : 4.0
# slope_leftP : 0.74
# slope_right : 4.0
# slope_left : 0.72
# slope : 2
#
# count : 323
# slope_rightP : 4.0
# slope_leftP : 0.72
# slope_right : 4.0
# slope_left : 1.06
# slope : 2
#
# count : 324
# slope_rightP : 4.0
# slope_leftP : 1.06
# slope_right : 4.0
# slope_left : 0.89
# slope : 2
#
# count : 325
# slope_rightP : 4.0
# slope_leftP : 0.89
# slope_right : 4.0
# slope_left : 0.69
# slope : 2
#
# count : 326
# slope_rightP : 4.0
# slope_leftP : 0.69
# slope_right : 4.0
# slope_left : 0.87
# slope : 2
#
# count : 327
# slope_rightP : 4.0
# slope_leftP : 0.87
# slope_right : 4.0
# slope_left : 0.77
# slope : 2
#
# count : 328
# slope_rightP : 4.0
# slope_leftP : 0.77
# slope_right : 4.0
# slope_left : 0.66
# slope : 2
#
# count : 329
# slope_rightP : 4.0
# slope_leftP : 0.66
# slope_right : 4.0
# slope_left : 0.76
# slope : 2
#
# count : 330
# slope_rightP : 4.0
# slope_leftP : 0.76
# slope_right : 4.0
# slope_left : 0.79
# slope : 2
#
# count : 331
# slope_rightP : 4.0
# slope_leftP : 0.79
# slope_right : 4.0
# slope_left : 0.61
# slope : 2
#
# count : 332
# slope_rightP : 4.0
# slope_leftP : 0.61
# slope_right : 3.75
# slope_left : 0.85
# slope : 2
#
# count : 333
# slope_rightP : 3.75
# slope_leftP : 0.85
# slope_right : -2.5
# slope_left : 0.92
# slope : -1.58
#
# count : 334
# slope_rightP : -2.5
# slope_leftP : 0.92
# slope_right : -4.33
# slope_left : 0.89
# slope : -2
#
# count : 335
# slope_rightP : -4.33
# slope_leftP : 0.89
# slope_right : -2.0
# slope_left : 1.01
# slope : -0.99
#
# count : 336
# slope_rightP : -2.0
# slope_leftP : 1.01
# slope_right : -4.67
# slope_left : 0.96
# slope : -2
#
# count : 337
# slope_rightP : -4.67
# slope_leftP : 0.96
# slope_right : -7.87
# slope_left : 1.01
# slope : -2
#
# count : 338
# slope_rightP : -7.87
# slope_leftP : 1.01
# slope_right : -4.65
# slope_left : 1.09
# slope : -2
#
# count : 339
# slope_rightP : -4.65
# slope_leftP : 1.09
# slope_right : -3.89
# slope_left : 1.34
# slope : -2
#
# count : 340
# slope_rightP : -3.89
# slope_leftP : 1.34
# slope_right : -4.97
# slope_left : 1.12
# slope : -2
#
# count : 341
# slope_rightP : -4.97
# slope_leftP : 1.12
# slope_right : -4.56
# slope_left : 1.48
# slope : -2
#
# count : 342
# slope_rightP : -4.56
# slope_leftP : 1.48
# slope_right : -2.99
# slope_left : 1.44
# slope : -1.55
#
# count : 343
# slope_rightP : -2.99
# slope_leftP : 1.44
# slope_right : -4.0
# slope_left : 1.36
# slope : -2
#
# count : 344
# slope_rightP : -4.0
# slope_leftP : 1.36
# slope_right : -3.98
# slope_left : 1.53
# slope : -2
#
# count : 345
# slope_rightP : -3.98
# slope_leftP : 1.53
# slope_right : -3.31
# slope_left : 1.52
# slope : -1.79
#
# count : 346
# slope_rightP : -3.31
# slope_leftP : 1.52
# slope_right : -4.81
# slope_left : 1.51
# slope : -2
#
# count : 347
# slope_rightP : -4.81
# slope_leftP : 1.51
# slope_right : -4.59
# slope_left : 1.81
# slope : -2
#
# count : 348
# slope_rightP : -4.59
# slope_leftP : 1.81
# slope_right : -2.91
# slope_left : 1.67
# slope : -1.24
#
# count : 349
# slope_rightP : -2.91
# slope_leftP : 1.67
# slope_right : -2.56
# slope_left : 1.55
# slope : -1.01
#
# count : 350
# slope_rightP : -2.56
# slope_leftP : 1.55
# slope_right : -2.52
# slope_left : 1.39
# slope : -1.13
#
# count : 351
# slope_rightP : -2.52
# slope_leftP : 1.39
# slope_right : -2.85
# slope_left : 1.95
# slope : -0.9
#
# count : 352
# slope_rightP : -2.85
# slope_leftP : 1.95
# slope_right : -3.62
# slope_left : 1.64
# slope : -1.98
#
# count : 353
# slope_rightP : -3.62
# slope_leftP : 1.64
# slope_right : -2.79
# slope_left : 1.2
# slope : -1.59
#
# count : 354
# slope_rightP : -2.79
# slope_leftP : 1.2
# slope_right : -2.32
# slope_left : 1.95
# slope : -0.37
#
# count : 355
# slope_rightP : -2.32
# slope_leftP : 1.95
# slope_right : -2.42
# slope_left : 2.18
# slope : -0.24
#
# count : 356
# slope_rightP : -2.42
# slope_leftP : 2.18
# slope_right : -2.19
# slope_left : 1.87
# slope : -0.32
#
# count : 357
# slope_rightP : -2.19
# slope_leftP : 1.87
# slope_right : -2.13
# slope_left : 1.9
# slope : -0.23
#
# count : 358
# slope_rightP : -2.13
# slope_leftP : 1.9
# slope_right : -2.63
# slope_left : 2.2
# slope : -0.43
#
# count : 359
# slope_rightP : -2.63
# slope_leftP : 2.2
# slope_right : -3.66
# slope_left : 2.16
# slope : -1.5
#
# count : 360
# slope_rightP : -3.66
# slope_leftP : 2.16
# slope_right : -2.22
# slope_left : 2.71
# slope : 0.49
#
# count : 361
# slope_rightP : -2.22
# slope_leftP : 2.71
# slope_right : -1.86
# slope_left : 2.3
# slope : 0.44
#
# count : 362
# slope_rightP : -1.86
# slope_leftP : 2.3
# slope_right : -2.02
# slope_left : 1.57
# slope : -0.45
#
# count : 363
# slope_rightP : -2.02
# slope_leftP : 1.57
# slope_right : -1.75
# slope_left : 2.32
# slope : 0.57
#
# count : 364
# slope_rightP : -1.75
# slope_leftP : 2.32
# slope_right : -1.95
# slope_left : 2.68
# slope : 0.73
#
# count : 365
# slope_rightP : -1.95
# slope_leftP : 2.68
# slope_right : -1.89
# slope_left : 2.14
# slope : 0.25
#
# count : 366
# slope_rightP : -1.89
# slope_leftP : 2.14
# slope_right : -2.18
# slope_left : 2.46
# slope : 0.28
#
# count : 367
# slope_rightP : -2.18
# slope_leftP : 2.46
# slope_right : -1.81
# slope_left : 2.23
# slope : 0.42
#
# count : 368
# slope_rightP : -1.81
# slope_leftP : 2.23
# slope_right : -2.3
# slope_left : 2.22
# slope : -0.08
#
# count : 369
# slope_rightP : -2.3
# slope_leftP : 2.22
# slope_right : -2.08
# slope_left : 2.21
# slope : 0.13
#
# count : 370
# slope_rightP : -2.08
# slope_leftP : 2.21
# slope_right : -1.55
# slope_left : 2.3
# slope : 0.75
#
# count : 371
# slope_rightP : -1.55
# slope_leftP : 2.3
# slope_right : -1.97
# slope_left : 2.11
# slope : 0.14
#
# count : 372
# slope_rightP : -1.97
# slope_leftP : 2.11
# slope_right : -2.9
# slope_left : 2.01
# slope : -0.89
#
# count : 373
# slope_rightP : -2.9
# slope_leftP : 2.01
# slope_right : -2.0
# slope_left : 0.06
# slope : -1.94
#
# count : 374
# slope_rightP : -2.0
# slope_leftP : 0.06
# slope_right : -2.14
# slope_left : 3.09
# slope : 0.95
#
# count : 375
# slope_rightP : -2.14
# slope_leftP : 3.09
# slope_right : -1.99
# slope_left : 2.77
# slope : 0.78
#
# count : 376
# slope_rightP : -1.99
# slope_leftP : 2.77
# slope_right : -1.9
# slope_left : 3.13
# slope : 1.23
#
# count : 377
# slope_rightP : -1.9
# slope_leftP : 3.13
# slope_right : -1.78
# slope_left : 1.69
# slope : -0.09
#
# count : 378
# slope_rightP : -1.78
# slope_leftP : 1.69
# slope_right : -1.38
# slope_left : 1.01
# slope : -0.37
#
# count : 379
# slope_rightP : -1.38
# slope_leftP : 1.01
# slope_right : -2.33
# slope_left : 2.79
# slope : 0.46
#
# count : 380
# slope_rightP : -2.33
# slope_leftP : 2.79
# slope_right : -1.97
# slope_left : 4.63
# slope : 2
#
# count : 381
# slope_rightP : -1.97
# slope_leftP : 4.63
# slope_right : -1.48
# slope_left : -0.52
# slope : -2.0
#
# count : 382
# slope_rightP : -1.48
# slope_leftP : -0.52
# slope_right : -1.73
# slope_left : 2.9
# slope : 1.17
#
# count : 383
# slope_rightP : -1.73
# slope_leftP : 2.9
# slope_right : -1.94
# slope_left : 2.02
# slope : 0.08
#
# count : 384
# slope_rightP : -1.94
# slope_leftP : 2.02
# slope_right : -2.37
# slope_left : 2.19
# slope : -0.18
#
# count : 385
# slope_rightP : -2.37
# slope_leftP : 2.19
# slope_right : -1.77
# slope_left : 2.34
# slope : 0.57
#
# count : 386
# slope_rightP : -1.77
# slope_leftP : 2.34
# slope_right : -2.36
# slope_left : 3.43
# slope : 1.07
#
# count : 387
# slope_rightP : -2.36
# slope_leftP : 3.43
# slope_right : -2.21
# slope_left : 2.92
# slope : 0.71
#
# count : 388
# slope_rightP : -2.21
# slope_leftP : 2.92
# slope_right : -1.84
# slope_left : 2.21
# slope : 0.37
#
# count : 389
# slope_rightP : -1.84
# slope_leftP : 2.21
# slope_right : -1.38
# slope_left : 2.13
# slope : 0.75
#
# count : 390
# slope_rightP : -1.38
# slope_leftP : 2.13
# slope_right : -1.48
# slope_left : 1.68
# slope : 0.2
#
# count : 391
# slope_rightP : -1.48
# slope_leftP : 1.68
# slope_right : -1.55
# slope_left : 1.93
# slope : 0.38
#
# count : 392
# slope_rightP : -1.55
# slope_leftP : 1.93
# slope_right : -1.71
# slope_left : 2.24
# slope : 0.53
#
# count : 393
# slope_rightP : -1.71
# slope_leftP : 2.24
# slope_right : -1.68
# slope_left : 3.87
# slope : 2
#
# count : 394
# slope_rightP : -1.68
# slope_leftP : 3.87
# slope_right : -1.82
# slope_left : 2.25
# slope : 0.43
#
# count : 395
# slope_rightP : -1.82
# slope_leftP : 2.25
# slope_right : -1.54
# slope_left : 1.97
# slope : 0.43
#
# count : 396
# slope_rightP : -1.54
# slope_leftP : 1.97
# slope_right : -1.84
# slope_left : 1.47
# slope : -0.37
#
# count : 397
# slope_rightP : -1.84
# slope_leftP : 1.47
# slope_right : -1.33
# slope_left : 2.26
# slope : 0.93
#
# count : 398
# slope_rightP : -1.33
# slope_leftP : 2.26
# slope_right : -1.9
# slope_left : 2.23
# slope : 0.33
#
# count : 399
# slope_rightP : -1.9
# slope_leftP : 2.23
# slope_right : -1.05
# slope_left : 3.31
# slope : 2
#
# count : 400
# slope_rightP : -1.05
# slope_leftP : 3.31
# slope_right : -1.7
# slope_left : 2.0
# slope : 0.3
#
# count : 401
# slope_rightP : -1.7
# slope_leftP : 2.0
# slope_right : -1.64
# slope_left : 5.39
# slope : 2
#
# count : 402
# slope_rightP : -1.64
# slope_leftP : 5.39
# slope_right : -1.98
# slope_left : 2.22
# slope : 0.24
#
# stop
# count : 403
# slope_rightP : -1.98
# slope_leftP : 2.22
# slope_right : -1.88
# slope_left : 1.98
# slope : 0.1
#
# stop
# count : 404
# slope_rightP : -1.88
# slope_leftP : 1.98
# slope_right : -1.75
# slope_left : 1.47
# slope : -0.28
#
# stop
# count : 405
# slope_rightP : -1.75
# slope_leftP : 1.47
# slope_right : -1.88
# slope_left : 2.23
# slope : 0.35
#
# stop
# count : 406
# slope_rightP : -1.88
# slope_leftP : 2.23
# slope_right : -1.89
# slope_left : 3.3
# slope : 1.41
#
# stop
# count : 407
# slope_rightP : -1.89
# slope_leftP : 3.3
# slope_right : -2.14
# slope_left : 2.3
# slope : 0.16
#
# stop
# count : 408
# slope_rightP : -2.14
# slope_leftP : 2.3
# slope_right : -3.4
# slope_left : 2.23
# slope : -1.17
#
# stop
# count : 409
# slope_rightP : -3.4
# slope_leftP : 2.23
# slope_right : -2.24
# slope_left : 2.18
# slope : -0.06
#
# stop
# count : 410
# slope_rightP : -2.24
# slope_leftP : 2.18
# slope_right : -1.99
# slope_left : 5.61
# slope : 2
#
# stop
# count : 411
# slope_rightP : -1.99
# slope_leftP : 5.61
# slope_right : -1.7
# slope_left : 5.48
# slope : 2
#
# stop
# count : 412
# slope_rightP : -1.7
# slope_leftP : 5.48
# slope_right : -2.43
# slope_left : 2.47
# slope : 0.04
#
# stop
# count : 413
# slope_rightP : -2.43
# slope_leftP : 2.47
# slope_right : -2.8
# slope_left : 2.03
# slope : -0.77
#
# stop
# count : 414
# slope_rightP : -2.8
# slope_leftP : 2.03
# slope_right : -2.35
# slope_left : 1.37
# slope : -0.98
#
# stop
# count : 415
# slope_rightP : -2.35
# slope_leftP : 1.37
# slope_right : -2.46
# slope_left : 3.01
# slope : 0.55
#
# stop
# count : 416
# slope_rightP : -2.46
# slope_leftP : 3.01
# slope_right : -2.42
# slope_left : 2.75
# slope : 0.33
#
# stop
# count : 417
# slope_rightP : -2.42
# slope_leftP : 2.75
# slope_right : -2.49
# slope_left : 2.03
# slope : -0.46
#
# stop
# count : 418
# slope_rightP : -2.49
# slope_leftP : 2.03
# slope_right : -1.77
# slope_left : 2.35
# slope : 0.58
#
# stop
# count : 419
# slope_rightP : -1.77
# slope_leftP : 2.35
# slope_right : -2.64
# slope_left : 4.34
# slope : 1.7
#
# stop
# count : 420
# slope_rightP : -2.64
# slope_leftP : 4.34
# slope_right : -1.91
# slope_left : 0.89
# slope : -1.02
#
# stop
# count : 421
# slope_rightP : -1.91
# slope_leftP : 0.89
# slope_right : -4.96
# slope_left : -1.75
# slope : -2
#
# stop
# count : 422
# slope_rightP : -4.96
# slope_leftP : -1.75
# slope_right : -2.81
# slope_left : 0.08
# slope : -2
#
# stop
# count : 423
# slope_rightP : -2.81
# slope_leftP : 0.08
# slope_right : -5.14
# slope_left : 0.72
# slope : -2
#
# stop
# count : 424
# slope_rightP : -5.14
# slope_leftP : 0.72
# slope_right : -1.23
# slope_left : 0.12
# slope : -1.11
#
# stop
# count : 425
# slope_rightP : -1.23
# slope_leftP : 0.12
# slope_right : -0.79
# slope_left : 0.39
# slope : -0.4
#
# stop
# count : 426
# slope_rightP : -0.79
# slope_leftP : 0.39
# slope_right : -0.92
# slope_left : 0.49
# slope : -0.43
#
# stop
# count : 427
# slope_rightP : -0.92
# slope_leftP : 0.49
# slope_right : -4.33
# slope_left : 1.91
# slope : -2
#
# stop
# count : 428
# slope_rightP : -4.33
# slope_leftP : 1.91
# slope_right : -4.33
# slope_left : 1.72
# slope : -2
#
# stop
# count : 429
# slope_rightP : -4.33
# slope_leftP : 1.72
# slope_right : -3.25
# slope_left : 0.21
# slope : -2
#
# stop
# count : 430
# slope_rightP : -3.25
# slope_leftP : 0.21
# slope_right : -3.25
# slope_left : 0.83
# slope : -2
#
# stop
# count : 431
# slope_rightP : -3.25
# slope_leftP : 0.83
# slope_right : -3.25
# slope_left : 0.32
# slope : -2
#
# stop
# count : 432
# slope_rightP : -3.25
# slope_leftP : 0.32
# slope_right : -2.35
# slope_left : 3.18
# slope : 0.83
#
# stop
# count : 433
# slope_rightP : -2.35
# slope_leftP : 3.18
# slope_right : -2.28
# slope_left : 0.44
# slope : -1.84
#
# stop
# count : 434
# slope_rightP : -2.28
# slope_leftP : 0.44
# slope_right : -2.53
# slope_left : 0.4
# slope : -2
#
# stop
# count : 435
# slope_rightP : -2.53
# slope_leftP : 0.4
# slope_right : -2.53
# slope_left : -0.78
# slope : -2
#
# stop
# count : 436
# slope_rightP : -2.53
# slope_leftP : -0.78
# slope_right : -2.53
# slope_left : 0.28
# slope : -2
#
# stop
# count : 437
# slope_rightP : -2.53
# slope_leftP : 0.28
# slope_right : -2.53
# slope_left : 1.15
# slope : -1.38
#
# stop
# count : 438
# slope_rightP : -2.53
# slope_leftP : 1.15
# slope_right : -2.53
# slope_left : 1.4
# slope : -1.13
#
# stop
# count : 439
# slope_rightP : -2.53
# slope_leftP : 1.4
# slope_right : -2.53
# slope_left : 1.14
# slope : -1.39
#
# stop
# count : 440
# slope_rightP : -2.53
# slope_leftP : 1.14
# slope_right : -2.53
# slope_left : 0.36
# slope : -2
#
# stop
# count : 441
# slope_rightP : -2.53
# slope_leftP : 0.36
# slope_right : -2.53
# slope_left : 0.76
# slope : -1.77
#
# stop
# count : 442
# slope_rightP : -2.53
# slope_leftP : 0.76
# slope_right : -2.53
# slope_left : 0.35
# slope : -2
#
# stop
# count : 443
# slope_rightP : -2.53
# slope_leftP : 0.35
# slope_right : 0.24
# slope_left : 0.33
# slope : 0.57
#
# stop
# count : 444
# slope_rightP : 0.24
# slope_leftP : 0.33
# slope_right : 0.24
# slope_left : -0.49
# slope : -0.25
#
# stop
# count : 445
# slope_rightP : 0.24
# slope_leftP : -0.49
# slope_right : 0.24
# slope_left : 0.04
# slope : 0.28
#
# stop
# count : 446
# slope_rightP : 0.24
# slope_leftP : 0.04
# slope_right : 0.24
# slope_left : 0.25
# slope : 0.49
#
# stop
# count : 447
# slope_rightP : 0.24
# slope_leftP : 0.25
# slope_right : 0.24
# slope_left : 0.73
# slope : 0.97
#
# stop
# count : 448
# slope_rightP : 0.24
# slope_leftP : 0.73
# slope_right : 0.2
# slope_left : -0.36
# slope : -0.16
#
# stop
# count : 449
# slope_rightP : 0.2
# slope_leftP : -0.36
# slope_right : 0.2
# slope_left : 0.08
# slope : 0.28
#
# stop
# count : 450
# slope_rightP : 0.2
# slope_leftP : 0.08
# slope_right : 0.2
# slope_left : 0.58
# slope : 0.78
#
# stop
# count : 451
# slope_rightP : 0.2
# slope_leftP : 0.58
# slope_right : -0.92
# slope_left : -0.27
# slope : -1.19
#
# stop
# count : 452
# slope_rightP : -0.92
# slope_leftP : -0.27
# slope_right : 0.68
# slope_left : 0.25
# slope : 0.93
#
# stop
# count : 453
# slope_rightP : 0.68
# slope_leftP : 0.25
# slope_right : 0.68
# slope_left : 0.28
# slope : 0.96
#
# stop
# count : 454
# slope_rightP : 0.68
# slope_leftP : 0.28
# slope_right : 0.68
# slope_left : 0.89
# slope : 1.57
#
# stop
# count : 455
# slope_rightP : 0.68
# slope_leftP : 0.89
# slope_right : 0.68
# slope_left : 1.1
# slope : 1.78
#
# stop
# count : 456
# slope_rightP : 0.68
# slope_leftP : 1.1
# slope_right : 0.68
# slope_left : 1.04
# slope : 1.72
#
# stop
# count : 457
# slope_rightP : 0.68
# slope_leftP : 1.04
# slope_right : 0.68
# slope_left : -0.21
# slope : 0.47
#
# stop
# count : 458
# slope_rightP : 0.68
# slope_leftP : -0.21
# slope_right : 0.68
# slope_left : 0.27
# slope : 0.95
#
# stop
# count : 459
# slope_rightP : 0.68
# slope_leftP : 0.27
# slope_right : -1.1
# slope_left : -2.16
# slope : -2
#
# stop
# count : 460
# slope_rightP : -1.1
# slope_leftP : -2.16
# slope_right : 0.58
# slope_left : -1.07
# slope : -0.49
#
# stop
# count : 461
# slope_rightP : 0.58
# slope_leftP : -1.07
# slope_right : 0.58
# slope_left : 1.34
# slope : 1.92
#
# stop
# count : 462
# slope_rightP : 0.58
# slope_leftP : 1.34
# slope_right : 0.58
# slope_left : -0.45
# slope : 0.13
#
# stop
# count : 463
# slope_rightP : 0.58
# slope_leftP : -0.45
# slope_right : 0.58
# slope_left : 0.49
# slope : 1.07
#
# stop
# count : 464
# slope_rightP : 0.58
# slope_leftP : 0.49
# slope_right : 0.58
# slope_left : -0.44
# slope : 0.14
#
# stop
# count : 465
# slope_rightP : 0.58
# slope_leftP : -0.44
# slope_right : 0.58
# slope_left : -0.33
# slope : 0.25
#
# stop
# count : 466
# slope_rightP : 0.58
# slope_leftP : -0.33
# slope_right : 0.58
# slope_left : -1.39
# slope : -0.81
#
# stop
# count : 467
# slope_rightP : 0.58
# slope_leftP : -1.39
# slope_right : 0.58
# slope_left : -0.18
# slope : 0.4
#
# stop
# count : 468
# slope_rightP : 0.58
# slope_leftP : -0.18
# slope_right : 0.48
# slope_left : 0.89
# slope : 1.37
#
# stop
# count : 469
# slope_rightP : 0.48
# slope_leftP : 0.89
# slope_right : 0.48
# slope_left : 1.3
# slope : 1.78
#
# stop
# count : 470
# slope_rightP : 0.48
# slope_leftP : 1.3
# slope_right : 0.48
# slope_left : 0.24
# slope : 0.72
#
# stop
# count : 471
# slope_rightP : 0.48
# slope_leftP : 0.24
# slope_right : 0.48
# slope_left : -0.6
# slope : -0.12
#
# stop
# count : 472
# slope_rightP : 0.48
# slope_leftP : -0.6
# slope_right : 0.48
# slope_left : -0.0
# slope : 0.48
#
# stop
# count : 473
# slope_rightP : 0.48
# slope_leftP : -0.0
# slope_right : -0.28
# slope_left : 1.08
# slope : 0.8
#
# stop
# count : 474
# slope_rightP : -0.28
# slope_leftP : 1.08
# slope_right : -0.28
# slope_left : 0.38
# slope : 0.1
#
# stop
# count : 475
# slope_rightP : -0.28
# slope_leftP : 0.38
# slope_right : -0.28
# slope_left : 1.0
# slope : 0.72
#
# stop
# count : 476
# slope_rightP : -0.28
# slope_leftP : 1.0
# slope_right : -0.28
# slope_left : 0.25
# slope : -0.03
#
# stop
# count : 477
# slope_rightP : -0.28
# slope_leftP : 0.25
# slope_right : -0.28
# slope_left : 0.07
# slope : -0.21
#
# stop
# count : 478
# slope_rightP : -0.28
# slope_leftP : 0.07
# slope_right : -0.28
# slope_left : 0.52
# slope : 0.24
#
# stop
# count : 479
# slope_rightP : -0.28
# slope_leftP : 0.52
# slope_right : -0.28
# slope_left : 0.47
# slope : 0.19
#
# stop
# count : 480
# slope_rightP : -0.28
# slope_leftP : 0.47
# slope_right : 0.05
# slope_left : 0.5
# slope : 0.55
#
# stop
# count : 481
# slope_rightP : 0.05
# slope_leftP : 0.5
# slope_right : 0.05
# slope_left : 0.35
# slope : 0.4
#
# stop
# count : 482
# slope_rightP : 0.05
# slope_leftP : 0.35
# slope_right : 0.05
# slope_left : -0.57
# slope : -0.52
#
# stop
# count : 483
# slope_rightP : 0.05
# slope_leftP : -0.57
# slope_right : 0.08
# slope_left : 0.26
# slope : 0.34
#
# stop
# count : 484
# slope_rightP : 0.08
# slope_leftP : 0.26
# slope_right : 0.08
# slope_left : 0.44
# slope : 0.52
#
# stop
# count : 485
# slope_rightP : 0.08
# slope_leftP : 0.44
# slope_right : 0.02
# slope_left : 0.75
# slope : 0.77
#
# stop
# count : 486
# slope_rightP : 0.02
# slope_leftP : 0.75
# slope_right : 0.09
# slope_left : -0.39
# slope : -0.3
#
# stop
# count : 487
# slope_rightP : 0.09
# slope_leftP : -0.39
# slope_right : 0.09
# slope_left : 0.44
# slope : 0.53
#
# stop
# count : 488
# slope_rightP : 0.09
# slope_leftP : 0.44
# slope_right : -1.92
# slope_left : 1.61
# slope : -0.31
#
# stop
# count : 489
# slope_rightP : -1.92
# slope_leftP : 1.61
# slope_right : -1.92
# slope_left : -0.9
# slope : -2
#
# stop
# count : 490
# slope_rightP : -1.92
# slope_leftP : -0.9
# slope_right : -1.92
# slope_left : -0.41
# slope : -2
#
# stop
# count : 491
# slope_rightP : -1.92
# slope_leftP : -0.41
# slope_right : -1.92
# slope_left : 1.22
# slope : -0.7
#
# stop
# count : 492
# slope_rightP : -1.92
# slope_leftP : 1.22
# slope_right : 0.18
# slope_left : 1.35
# slope : 1.53
#
# stop
# count : 493
# slope_rightP : 0.18
# slope_leftP : 1.35
# slope_right : 0.18
# slope_left : 1.33
# slope : 1.51
#
# stop
# count : 494
# slope_rightP : 0.18
# slope_leftP : 1.33
# slope_right : 0.18
# slope_left : 0.14
# slope : 0.32
#
# stop
# count : 495
# slope_rightP : 0.18
# slope_leftP : 0.14
# slope_right : 0.05
# slope_left : 0.49
# slope : 0.54
#
# stop
# count : 496
# slope_rightP : 0.05
# slope_leftP : 0.49
# slope_right : -0.92
# slope_left : 0.81
# slope : -0.11
#
# stop
# count : 497
# slope_rightP : -0.92
# slope_leftP : 0.81
# slope_right : -0.92
# slope_left : 0.06
# slope : -0.86
#
# stop
# count : 498
# slope_rightP : -0.92
# slope_leftP : 0.06
# slope_right : -0.92
# slope_left : 0.09
# slope : -0.83
#
# stop
# count : 499
# slope_rightP : -0.92
# slope_leftP : 0.09
# slope_right : -0.92
# slope_left : -0.18
# slope : -1.1
#
# stop
# count : 500
# slope_rightP : -0.92
# slope_leftP : -0.18
# slope_right : -0.92
# slope_left : -0.27
# slope : -1.19
#
# stop
# count : 501
# slope_rightP : -0.92
# slope_leftP : -0.27
# slope_right : -1.27
# slope_left : 1.05
# slope : -0.22
#
# stop
# count : 502
# slope_rightP : -1.27
# slope_leftP : 1.05
# slope_right : -1.27
# slope_left : -0.3
# slope : -1.57
#
# stop
# count : 503
# slope_rightP : -1.27
# slope_leftP : -0.3
# slope_right : -1.27
# slope_left : 0.95
# slope : -0.32
#
# stop
# count : 504
# slope_rightP : -1.27
# slope_leftP : 0.95
# slope_right : 0.12
# slope_left : 0.42
# slope : 0.54
#
# stop
# count : 505
# slope_rightP : 0.12
# slope_leftP : 0.42
# slope_right : 0.12
# slope_left : 1.84
# slope : 1.96
#
# stop
# count : 506
# slope_rightP : 0.12
# slope_leftP : 1.84
# slope_right : 0.12
# slope_left : 0.2
# slope : 0.32
#
# stop
# count : 507
# slope_rightP : 0.12
# slope_leftP : 0.2
# slope_right : 0.12
# slope_left : -0.3
# slope : -0.18
#
# stop
# count : 508
# slope_rightP : 0.12
# slope_leftP : -0.3
# slope_right : 0.12
# slope_left : -0.1
# slope : 0.02
#
# stop
# count : 509
# slope_rightP : 0.12
# slope_leftP : -0.1
# slope_right : 0.12
# slope_left : 0.15
# slope : 0.27
#
# stop
# count : 510
# slope_rightP : 0.12
# slope_leftP : 0.15
# slope_right : -2.08
# slope_left : 0.31
# slope : -1.77
#
# stop
# count : 511
# slope_rightP : -2.08
# slope_leftP : 0.31
# slope_right : -2.08
# slope_left : 0.13
# slope : -1.95
#
# stop
# count : 512
# slope_rightP : -2.08
# slope_leftP : 0.13
# slope_right : -2.08
# slope_left : -0.99
# slope : -2
#
# stop
# count : 513
# slope_rightP : -2.08
# slope_leftP : -0.99
# slope_right : -2.08
# slope_left : 0.03
# slope : -2
#
# stop
# count : 514
# slope_rightP : -2.08
# slope_leftP : 0.03
# slope_right : -2.08
# slope_left : 0.4
# slope : -1.68
#
# stop
# count : 515
# slope_rightP : -2.08
# slope_leftP : 0.4
# slope_right : -2.08
# slope_left : 0.13
# slope : -1.95
#
# stop
# count : 516
# slope_rightP : -2.08
# slope_leftP : 0.13
# slope_right : -2.37
# slope_left : 4.39
# slope : 2
#
# stop
# count : 517
# slope_rightP : -2.37
# slope_leftP : 4.39
# slope_right : -0.4
# slope_left : 2.41
# slope : 2
#
# stop
# count : 518
# slope_rightP : -0.4
# slope_leftP : 2.41
# slope_right : -0.4
# slope_left : 0.18
# slope : -0.22
#
# stop
# count : 519
# slope_rightP : -0.4
# slope_leftP : 0.18
# slope_right : -0.4
# slope_left : 0.53
# slope : 0.13
#
# stop
# count : 520
# slope_rightP : -0.4
# slope_leftP : 0.53
# slope_right : -0.4
# slope_left : -0.33
# slope : -0.73
#
# stop
# count : 521
# slope_rightP : -0.4
# slope_leftP : -0.33
# slope_right : -0.4
# slope_left : 0.0
# slope : -0.4
#
# stop
# count : 522
# slope_rightP : -0.4
# slope_leftP : 0.0
# slope_right : -0.4
# slope_left : 2.04
# slope : 1.64
#
# stop
# count : 523
# slope_rightP : -0.4
# slope_leftP : 2.04
# slope_right : -0.4
# slope_left : 0.39
# slope : -0.01
#
# stop
# count : 524
# slope_rightP : -0.4
# slope_leftP : 0.39
# slope_right : -0.4
# slope_left : 1.01
# slope : 0.61
# stop
# count : 525
# slope_rightP : -0.4
# slope_leftP : 1.01
# slope_right : -2.68
# slope_left : 3.39
# slope : 0.71
#
# stop
# count : 526
# slope_rightP : -2.68
# slope_leftP : 3.39
# slope_right : -1.7
# slope_left : 1.03
# slope : -0.67
#
# stop
# count : 527
# slope_rightP : -1.7
# slope_leftP : 1.03
# slope_right : -1.7
# slope_left : -0.4
# slope : -2
#
# stop
# count : 528
# slope_rightP : -1.7
# slope_leftP : -0.4
# slope_right : -1.45
# slope_left : 2.06
# slope : 0.61
#
# stop
# count : 529
# slope_rightP : -1.45
# slope_leftP : 2.06
# slope_right : -3.54
# slope_left : 1.6
# slope : -1.94
#
# stop
# count : 530
# slope_rightP : -3.54
# slope_leftP : 1.6
# slope_right : -2.25
# slope_left : -0.44
# slope : -2
#
# stop
# count : 531
# slope_rightP : -2.25
# slope_leftP : -0.44
# slope_right : -0.54
# slope_left : 0.69
# slope : 0.15
#
# stop
# count : 532
# slope_rightP : -0.54
# slope_leftP : 0.69
# slope_right : -0.54
# slope_left : 1.21
# slope : 0.67
#
# stop
# count : 533
# slope_rightP : -0.54
# slope_leftP : 1.21
# slope_right : -1.89
# slope_left : 0.49
# slope : -1.4
#
# stop
# count : 534
# slope_rightP : -1.89
# slope_leftP : 0.49
# slope_right : -1.89
# slope_left : 0.07
# slope : -1.82
#
# stop
# count : 535
# slope_rightP : -1.89
# slope_leftP : 0.07
# slope_right : -1.89
# slope_left : -0.23
# slope : -2
#
# stop
# count : 536
# slope_rightP : -1.89
# slope_leftP : -0.23
# slope_right : -1.89
# slope_left : -0.27
# slope : -2
#
# stop
# count : 537
# slope_rightP : -1.89
# slope_leftP : -0.27
# slope_right : -1.89
# slope_left : -1.54
# slope : -2
#
# stop
# count : 538
# slope_rightP : -1.89
# slope_leftP : -1.54
# slope_right : -1.89
# slope_left : -1.19
# slope : -2
#
# stop
# count : 539
# slope_rightP : -1.89
# slope_leftP : -1.19
# slope_right : -1.89
# slope_left : 0.29
# slope : -1.6
#
# stop
# count : 540
# slope_rightP : -1.89
# slope_leftP : 0.29
# slope_right : -1.89
# slope_left : -0.23
# slope : -2
#
# stop
# count : 541
# slope_rightP : -1.89
# slope_leftP : -0.23
# slope_right : -1.89
# slope_left : 0.43
# slope : -1.46
#
# stop
# count : 542
# slope_rightP : -1.89
# slope_leftP : 0.43
# slope_right : -1.89
# slope_left : -0.05
# slope : -1.94
#
# stop
# count : 543
# slope_rightP : -1.89
# slope_leftP : -0.05
# slope_right : -2.0
# slope_left : -0.03
# slope : -2
#
# stop
# count : 544
# slope_rightP : -2.0
# slope_leftP : -0.03
# slope_right : 0.27
# slope_left : 0.65
# slope : 0.92
#
# stop
# count : 545
# slope_rightP : 0.27
# slope_leftP : 0.65
# slope_right : 0.05
# slope_left : 0.95
# slope : 1.0
#
# stop
# count : 546
# slope_rightP : 0.05
# slope_leftP : 0.95
# slope_right : 0.05
# slope_left : 0.08
# slope : 0.13
#
# stop
# count : 547
# slope_rightP : 0.05
# slope_leftP : 0.08
# slope_right : 0.05
# slope_left : 0.38
# slope : 0.43
#
# stop
# count : 548
# slope_rightP : 0.05
# slope_leftP : 0.38
# slope_right : 0.05
# slope_left : 0.15
# slope : 0.2
#
# stop
# count : 549
# slope_rightP : 0.05
# slope_leftP : 0.15
# slope_right : 0.05
# slope_left : 0.08
# slope : 0.13
#
# stop
# count : 550
# slope_rightP : 0.05
# slope_leftP : 0.08
# slope_right : 0.05
# slope_left : 0.76
# slope : 0.81
#
# stop
# count : 551
# slope_rightP : 0.05
# slope_leftP : 0.76
# slope_right : 0.21
# slope_left : 1.05
# slope : 1.26
#
# stop
# count : 552
# slope_rightP : 0.21
# slope_leftP : 1.05
# slope_right : 4.33
# slope_left : 1.34
# slope : 2
#
# stop
# count : 553
# slope_rightP : 4.33
# slope_leftP : 1.34
# slope_right : 4.33
# slope_left : 1.31
# slope : 2
#
# stop
# count : 554
# slope_rightP : 4.33
# slope_leftP : 1.31
# slope_right : -4.03
# slope_left : 0.03
# slope : -2
#
# stop
# count : 555
# slope_rightP : -4.03
# slope_leftP : 0.03
# slope_right : -4.03
# slope_left : -0.14
# slope : -2
#
# stop
# count : 556
# slope_rightP : -4.03
# slope_leftP : -0.14
# slope_right : -4.03
# slope_left : -0.09
# slope : -2
#
# stop
# count : 557
# slope_rightP : -4.03
# slope_leftP : -0.09
# slope_right : -4.03
# slope_left : 0.05
# slope : -2
#
# stop
# count : 558
# slope_rightP : -4.03
# slope_leftP : 0.05
# slope_right : -4.03
# slope_left : -0.16
# slope : -2
#
# stop
# count : 559
# slope_rightP : -4.03
# slope_leftP : -0.16
# slope_right : -4.03
# slope_left : -0.04
# slope : -2
#
# stop
# count : 560
# slope_rightP : -4.03
# slope_leftP : -0.04
# slope_right : -4.03
# slope_left : 0.58
# slope : -2
#
# stop
# count : 561
# slope_rightP : -4.03
# slope_leftP : 0.58
# slope_right : -4.03
# slope_left : 0.68
# slope : -2
#
# stop
# count : 562
# slope_rightP : -4.03
# slope_leftP : 0.68
# slope_right : -4.03
# slope_left : 0.61
# slope : -2
#
# stop
# count : 563
# slope_rightP : -4.03
# slope_leftP : 0.61
# slope_right : -4.03
# slope_left : -0.84
# slope : -2
#
# stop
# count : 564
# slope_rightP : -4.03
# slope_leftP : -0.84
# slope_right : -4.03
# slope_left : 0.98
# slope : -2
#
# stop
# count : 565
# slope_rightP : -4.03
# slope_leftP : 0.98
# slope_right : -4.03
# slope_left : 0.68
# slope : -2
#
# stop
# count : 566
# slope_rightP : -4.03
# slope_leftP : 0.68
# slope_right : -4.03
# slope_left : 0.53
# slope : -2
#
# stop
# count : 567
# slope_rightP : -4.03
# slope_leftP : 0.53
# slope_right : -4.03
# slope_left : -1.29
# slope : -2
#
# stop
# count : 568
# slope_rightP : -4.03
# slope_leftP : -1.29
# slope_right : -4.03
# slope_left : -0.0
# slope : -2
#
# stop
# count : 569
# slope_rightP : -4.03
# slope_leftP : -0.0
# slope_right : -4.03
# slope_left : 0.35
# slope : -2
#
# stop
# count : 570
# slope_rightP : -4.03
# slope_leftP : 0.35
# slope_right : -4.03
# slope_left : 1.04
# slope : -2
#
# stop
# count : 571
# slope_rightP : -4.03
# slope_leftP : 1.04
# slope_right : -4.03
# slope_left : 0.01
# slope : -2
#
# stop
# count : 572
# slope_rightP : -4.03
# slope_leftP : 0.01
# slope_right : 0.12
# slope_left : -1.26
# slope : -1.14
#
# stop
# count : 573
# slope_rightP : 0.12
# slope_leftP : -1.26
# slope_right : 0.32
# slope_left : 0.13
# slope : 0.45
#
# stop
# count : 574
# slope_rightP : 0.32
# slope_leftP : 0.13
# slope_right : 0.05
# slope_left : 1.9
# slope : 1.95
#
# stop
# count : 575
# slope_rightP : 0.05
# slope_leftP : 1.9
# slope_right : -3.5
# slope_left : 2.18
# slope : -1.32
#
# stop
# count : 576
# slope_rightP : -3.5
# slope_leftP : 2.18
# slope_right : 0.09
# slope_left : 0.1
# slope : 0.19
#
# stop
# count : 577
# slope_rightP : 0.09
# slope_leftP : 0.1
# slope_right : 0.09
# slope_left : 0.6
# slope : 0.69
#
# stop
# count : 578
# slope_rightP : 0.09
# slope_leftP : 0.6
# slope_right : 0.09
# slope_left : -1.03
# slope : -0.94
#
# stop
# count : 579
# slope_rightP : 0.09
# slope_leftP : -1.03
# slope_right : -1.5
# slope_left : 0.37
# slope : -1.13
#
# stop
# count : 580
# slope_rightP : -1.5
# slope_leftP : 0.37
# slope_right : -1.5
# slope_left : 0.21
# slope : -1.29
#
# stop
# count : 581
# slope_rightP : -1.5
# slope_leftP : 0.21
# slope_right : -1.5
# slope_left : 2.35
# slope : 0.85
#
# stop
# count : 582
# slope_rightP : -1.5
# slope_leftP : 2.35
# slope_right : -1.5
# slope_left : 0.28
# slope : -1.22
#
# stop
# count : 583
# slope_rightP : -1.5
# slope_leftP : 0.28
# slope_right : -1.5
# slope_left : 0.68
# slope : -0.82
#
# stop
# count : 584
# slope_rightP : -1.5
# slope_leftP : 0.68
# slope_right : -1.5
# slope_left : 0.4
# slope : -1.1
#
# stop
# count : 585
# slope_rightP : -1.5
# slope_leftP : 0.4
# slope_right : -1.5
# slope_left : -0.02
# slope : -1.52
#
# stop
# count : 586
# slope_rightP : -1.5
# slope_leftP : -0.02
# slope_right : -1.5
# slope_left : 0.9
# slope : -0.6
#
# stop
# count : 587
# slope_rightP : -1.5
# slope_leftP : 0.9
# slope_right : -1.5
# slope_left : 0.1
# slope : -1.4
#
# stop
# count : 588
# slope_rightP : -1.5
# slope_leftP : 0.1
# slope_right : -1.5
# slope_left : 0.97
# slope : -0.53
#
# stop
# count : 589
# slope_rightP : -1.5
# slope_leftP : 0.97
# slope_right : -1.5
# slope_left : 1.84
# slope : 0.34
#
# stop
# count : 590
# slope_rightP : -1.5
# slope_leftP : 1.84
# slope_right : -1.5
# slope_left : -0.57
# slope : -2
#
# stop
# count : 591
# slope_rightP : -1.5
# slope_leftP : -0.57
# slope_right : -1.5
# slope_left : -0.55
# slope : -2
#
# stop
# count : 592
# slope_rightP : -1.5
# slope_leftP : -0.55
# slope_right : -1.5
# slope_left : -0.24
# slope : -1.74
#
# stop
# count : 593
# slope_rightP : -1.5
# slope_leftP : -0.24
# slope_right : -1.5
# slope_left : 1.33
# slope : -0.17
#
# stop
# count : 594
# slope_rightP : -1.5
# slope_leftP : 1.33
# slope_right : -2.25
# slope_left : 0.36
# slope : -1.89
#
# stop
# count : 595
# slope_rightP : -2.25
# slope_leftP : 0.36
# slope_right : -1.49
# slope_left : 0.95
# slope : -0.54
#
# stop
# count : 596
# slope_rightP : -1.49
# slope_leftP : 0.95
# slope_right : 0.22
# slope_left : -0.01
# slope : 0.21
#
# stop
# count : 597
# slope_rightP : 0.22
# slope_leftP : -0.01
# slope_right : 0.22
# slope_left : 0.27
# slope : 0.49
#
# stop
# count : 598
# slope_rightP : 0.22
# slope_leftP : 0.27
# slope_right : 0.12
# slope_left : 0.28
# slope : 0.4
#
# Can't receive frame (stream end?). Exiting ...

# %%
a=[2,3,4,5]

# %%
from scipy import stats
b = stats.mode(a)

# %%
print(b.mode[0])
# Out:
# 2

# %%
import cv2
import numpy as np
from scipy import ndimage as ndi
from skimage.morphology import square,dilation
from skimage.io import imshow
from scipy import stats
import time
class HoughTransform:
    
    def __init__(self,filename = 'test.h264',threshold = 40):
        self.url = '../../video/' + filename
        self.cap = cv2.VideoCapture(self.url)
        self.countR = 0
        self.left = []
        self.right = []
        self.ret = 0
        self.frame = 0
        self.slope_right = 0
        self.slope_left = 0
        self.slope = 0
        self.slope_rightP = 0
        self.slope_leftP = 0
        self.font = cv2.FONT_HERSHEY_SIMPLEX
        self.threshold = threshold
        self.red = False
        
    def _debug(self,debug = True):
        if (debug):            
#             cv2.putText(self.frame,str(self.slope_right),(100,25), self.font, 0.5,(255,255,255),2,cv2.LINE_AA)
            
            
            print('slope_rightP :',self.slope_rightP)
            print('slope_leftP :',self.slope_leftP)
            print('slope_right :', self.slope_right)            
            print('slope_left :', self.slope_left)            
            print('slope :', self.slope)
            print()

    
    def region_of_interest(self,img, vertices):
        mask = np.zeros_like(img)
        match_mask_color = (255,)
        cv2.fillPoly(mask, vertices, 255)
        masked_image = cv2.bitwise_and(img, mask)
        return masked_image

    def findSlope(self,start,end,width):
        x1 = start[0]
        x2 = end[0]
        y1 = width-start[1]
        y2 = width-end[1]
        if (x2 - x1) != 0:
            m = (y2-y1)/(x2-x1)
            return m 
        
    def run(self,image=0,fromvideo = False,debugs = False):
        if(fromvideo):
            while self.cap.isOpened():
                self.ret, self.frame = self.cap.read()
                if not self.ret:
                    print("Can't receive frame (stream end?). Exiting ...")
                    break                
                if cv2.waitKey(1) == ord('q'):
                    break
                if self.red:
                    break
                self.corerun()                    
                self._debug(debug = debugs)
            self.cap.release()
            cv2.destroyAllWindows()
        else:
            self.frame = image
            while cv2.waitKey(1) != ord('q'):                
                self.corerun()  
                self._debug(debug = debugs)
                if self.red:
                    return 3
                else:
                    return float(self.slope)
            self.cap.release()
            cv2.destroyAllWindows()
            
        
    def corerun(self):         
        self.frame = cv2.resize(self.frame,(100, 75))    
        height=self.frame.shape[0]
        width=self.frame.shape[1]
        region_of_interest_vertices = [   
            (0, height),
            (0, (height/3)+10),
            (width, (height/3)+10),
            (width, height)]
        
        gray=cv2.cvtColor(self.frame, cv2.COLOR_RGB2GRAY)

        edges = cv2.Canny(gray,100,200)
        edges = dilation(edges, square(3))
        # edges[:,width-3:width] = 0 
        # edges = ndi.gaussian_filter(edges,2)
        
        crop = self.region_of_interest(edges,np.array([region_of_interest_vertices], np.int32))
        self.frame=cv2.cvtColor(self.frame, cv2.COLOR_BGR2RGB)    
        lowerR=np.array([220,70,70])
        upperR=np.array([255,160,170])    
        maskR = cv2.inRange(self.frame, lowerR, upperR)
        
        for i in range(width):        
            if maskR[int(height/3)][i] == 255: 
                self.countR+=1
            if self.countR > 10:
                self.red = True
                return

        # Hough Transform
        lines = cv2.HoughLinesP(crop,rho = 1,theta = 1*np.pi/180,threshold = self.threshold,minLineLength = 10,maxLineGap = 250)
        font = cv2.FONT_HERSHEY_SIMPLEX
        l=[]
        r=[]

        # Draw lines on the image
        if(lines is not None) :
            for line in lines:  
                x1, y1, x2, y2 = line[0]
                if(self.findSlope((x1,y1),(x2,y2),width)):
                    if(x1 < int(width/2)):
                        l.append([x1,x2,y1,y2,])
                    else:
                        r.append([x1,x2,y1,y2,self.findSlope((x1,y1),(x2,y2),width)])

            l=np.array(l)
            r=np.array(r)
            self.slope_leftP = self.slope_left
            self.slope_rightP = self.slope_right
            # slope left
            if(len(l)):                
                modeL = stats.mode(l).mode[0].astype(int)
                self.slope_left = round(self.findSlope((modeL[0],modeL[2]),(modeL[1],modeL[3]),width),3)
                cv2.line(self.frame, (modeL[0], modeL[2]), (modeL[1], modeL[3]), (255, 0, 0), 3)
                print('modeL', modeL)
            else:
                self.slope_left = self.slope_leftP

            # slope right
            if(len(r)):                
                modeR = stats.mode(r).mode[0].astype(int)
                self.slope_right = round(self.findSlope((modeR[0],modeR[2]),(modeR[1],modeR[3]),width),3)
                cv2.line(self.frame, (modeR[0], modeR[2]), (modeR[1], modeR[3]), (0, 0, 255), 3)
                print('modeR', modeR)
            else:
                self.slope_right = self.slope_rightP
        print('allLeft: ',l)  
        print('allRight: ',r)
        
        print('lefy: ',self.slope_left, 'right:',self.slope_right)   
        self.slope = round(self.slope_right + self.slope_left,3)
        if(self.slope > 2):
            self.slope = 2
        elif(self.slope < -2):
            self.slope = -2  
            
#         self.frame=cv2.cvtColor(self.frame, cv2.COLOR_BGR2RGB)  
        cv2.putText(self.frame,str(self.slope),(10,20), self.font, 0.5,(255,255,255),2,cv2.LINE_AA)
        
#         time.sleep(0.05)
        cv2.imshow('frame', self.frame)

# %%
a = []
for i in range(3,30):
    image = cv2.imread('../dataset/original/'+ str(i) +'.jpg') 
    a.append(image)
             
h = HoughTransform(threshold=40)
for i in a:
    h.run(i,fromvideo=True,debugs=True)
# Out:
# modeL [ 1 19 74 35]
# modeR [77 97 35 73 -2]
# allLeft:  [[ 1 19 73 35]
#  [ 6 23 74 35]
#  [ 2 20 74 35]
#  [ 8 24 74 35]]
# allRight:  [[77.   97.   35.   74.   -1.95]
#  [79.   98.   35.   73.   -2.  ]]
# lefy:  2.167 right: -1.9
# slope_rightP : 0
# slope_leftP : 0
# slope_right : -1.9
# slope_left : 2.167
# slope : 0.267
#
# modeL [ 1 20 74 35]
# modeR [76 97 35 74 -1]
# allLeft:  [[ 1 20 74 35]
#  [ 7 23 73 35]
#  [ 8 24 74 35]]
# allRight:  [[79.         99.         35.         74.         -1.95      ]
#  [76.         97.         35.         74.         -1.85714286]]
# lefy:  2.053 right: -1.857
# slope_rightP : -1.9
# slope_leftP : 2.167
# slope_right : -1.857
# slope_left : 2.053
# slope : 0.196
#
# modeL [ 1 19 71 35]
# modeR [75 99 35 73 -1]
# allLeft:  [[ 1 20 73 35]
#  [ 1 19 71 36]
#  [ 7 23 74 35]
#  [ 8 24 73 35]
#  [ 7 22 71 35]]
# allRight:  [[75.         99.         36.         74.         -1.58333333]
#  [78.         99.         35.         73.         -1.80952381]]
# lefy:  2.0 right: -1.583
# slope_rightP : -1.857
# slope_leftP : 2.053
# slope_right : -1.583
# slope_left : 2.0
# slope : 0.417
#
# modeL [ 1 20 74 35]
# modeR [78 98 35 74 -1]
# allLeft:  [[ 7 23 74 35]
#  [ 1 22 74 35]
#  [ 1 20 72 35]
#  [ 8 24 73 35]]
# allRight:  [[78.   98.   35.   74.   -1.95]
#  [79.   99.   35.   74.   -1.95]]
# lefy:  2.053 right: -1.95
# slope_rightP : -1.583
# slope_leftP : 2.0
# slope_right : -1.95
# slope_left : 2.053
# slope : 0.103
#
# modeL [ 7 20 74 35]
# modeR [77 97 35 74 -1]
# allLeft:  [[ 1 20 73 35]
#  [ 7 23 74 35]
#  [ 8 24 74 35]
#  [ 7 22 72 35]]
# allRight:  [[77.         97.         35.         74.         -1.95      ]
#  [78.         99.         36.         74.         -1.80952381]]
# lefy:  3.0 right: -1.95
# slope_rightP : -1.95
# slope_leftP : 2.053
# slope_right : -1.95
# slope_left : 3.0
# slope : 1.05
#
# modeL [ 1 20 74 35]
# modeR [77 95 35 74 -2]
# allLeft:  [[ 1 22 74 35]
#  [ 7 23 74 35]
#  [ 8 25 74 35]
#  [ 1 20 72 35]]
# allRight:  [[79.         97.         35.         74.         -2.16666667]
#  [81.         99.         35.         74.         -2.16666667]
#  [77.         95.         35.         74.         -2.16666667]]
# lefy:  2.053 right: -2.167
# slope_rightP : -1.95
# slope_leftP : 3.0
# slope_right : -2.167
# slope_left : 2.053
# slope : -0.114
#
# modeL [ 2 18 74 35]
# modeR [75 99 35 74 -1]
# allLeft:  [[ 3 19 74 35]
#  [ 8 21 74 35]
#  [ 2 18 74 35]]
# allRight:  [[75.    99.    35.    74.    -1.625]]
# lefy:  2.438 right: -1.625
# slope_rightP : -2.167
# slope_leftP : 2.053
# slope_right : -1.625
# slope_left : 2.438
# slope : 0.813
#
# modeL [ 1 19 74 35]
# modeR [75 99 35 73 -1]
# allLeft:  [[ 1 21 73 35]
#  [ 8 23 74 35]
#  [ 1 19 71 35]
#  [ 7 22 74 35]]
# allRight:  [[75.         99.         35.         73.         -1.58333333]]
# lefy:  2.167 right: -1.583
# slope_rightP : -1.625
# slope_leftP : 2.438
# slope_right : -1.583
# slope_left : 2.167
# slope : 0.584
#
# modeL [ 1 18 74 35]
# modeR [77 95 35 74 -2]
# allLeft:  [[ 7 22 74 35]
#  [ 1 19 74 35]
#  [ 8 24 74 35]
#  [ 1 18 73 35]]
# allRight:  [[79.         97.         35.         74.         -2.16666667]
#  [77.         95.         35.         74.         -2.16666667]
#  [80.         98.         35.         74.         -2.16666667]]
# lefy:  2.294 right: -2.167
# slope_rightP : -1.583
# slope_leftP : 2.167
# slope_right : -2.167
# slope_left : 2.294
# slope : 0.127
#
# modeL [ 1 18 74 35]
# modeR [76 99 35 74 -1]
# allLeft:  [[ 7 23 74 35]
#  [ 1 18 74 35]
#  [ 8 24 73 35]]
# allRight:  [[76.         99.         35.         74.         -1.69565217]]
# lefy:  2.294 right: -1.696
# slope_rightP : -2.167
# slope_leftP : 2.294
# slope_right : -1.696
# slope_left : 2.294
# slope : 0.598
#
# modeL [ 7 19 73 35]
# modeR [75 99 35 74 -1]
# allLeft:  [[ 1 19 73 35]
#  [ 7 25 73 35]
#  [ 2 19 74 36]
#  [ 7 23 71 35]]
# allRight:  [[75.    99.    35.    74.    -1.625]]
# lefy:  3.167 right: -1.625
# slope_rightP : -1.696
# slope_leftP : 2.294
# slope_right : -1.625
# slope_left : 3.167
# slope : 1.542
#
# modeL [ 1 20 73 35]
# modeR [75 99 35 72 -1]
# allLeft:  [[ 1 21 73 35]
#  [ 7 22 74 35]
#  [ 1 20 71 35]
#  [ 8 23 73 35]]
# allRight:  [[75.         99.         35.         74.         -1.625     ]
#  [77.         99.         35.         72.         -1.68181818]]
# lefy:  2.0 right: -1.542
# slope_rightP : -1.625
# slope_leftP : 3.167
# slope_right : -1.542
# slope_left : 2.0
# slope : 0.458
#
# modeL [ 2 18 74 35]
# modeR [77 97 35 74 -1]
# allLeft:  [[ 2 18 74 35]
#  [ 8 21 74 35]]
# allRight:  [[77.   97.   35.   74.   -1.95]
#  [78.   98.   35.   74.   -1.95]]
# lefy:  2.438 right: -1.95
# slope_rightP : -1.542
# slope_leftP : 2.0
# slope_right : -1.95
# slope_left : 2.438
# slope : 0.488
#
# modeL [ 0 20 74 35]
# modeR [76 97 35 74 -1]
# allLeft:  [[ 0 21 74 35]
#  [ 7 22 74 35]
#  [ 0 20 73 35]
#  [ 8 23 74 35]]
# allRight:  [[78.         98.         35.         74.         -1.95      ]
#  [76.         97.         35.         74.         -1.85714286]]
# lefy:  1.95 right: -1.857
# slope_rightP : -1.95
# slope_leftP : 2.438
# slope_right : -1.857
# slope_left : 1.95
# slope : 0.093
#
# modeL [ 7 19 70 35]
# modeR [78 97 35 74 -2]
# allLeft:  [[ 7 24 74 35]
#  [ 0 20 74 35]
#  [ 1 19 70 35]
#  [ 7 22 70 35]]
# allRight:  [[78.         97.         35.         74.         -2.05263158]
#  [81.         98.         35.         74.         -2.29411765]]
# lefy:  2.917 right: -2.053
# slope_rightP : -1.857
# slope_leftP : 1.95
# slope_right : -2.053
# slope_left : 2.917
# slope : 0.864
#
# modeL [ 0 18 74 35]
# modeR [76 97 35 74 -1]
# allLeft:  [[ 2 19 74 35]
#  [ 7 21 74 35]
#  [ 0 18 74 35]
#  [ 8 25 74 35]]
# allRight:  [[78.         98.         35.         74.         -1.95      ]
#  [76.         97.         35.         74.         -1.85714286]]
# lefy:  2.167 right: -1.857
# slope_rightP : -2.053
# slope_leftP : 2.917
# slope_right : -1.857
# slope_left : 2.167
# slope : 0.31
#
# modeL [ 7 20 74 35]
# modeR [74 98 35 74 -1]
# allLeft:  [[ 0 20 74 35]
#  [ 7 23 74 35]
#  [ 7 22 72 35]]
# allRight:  [[78.         99.         35.         74.         -1.85714286]
#  [74.         98.         35.         74.         -1.625     ]]
# lefy:  3.0 right: -1.625
# slope_rightP : -1.857
# slope_leftP : 2.167
# slope_right : -1.625
# slope_left : 3.0
# slope : 1.375
#
# modeL [ 2 17 74 35]
# modeR [75 99 35 73 -1]
# allLeft:  [[ 2 17 74 36]
#  [ 8 24 74 35]
#  [ 7 22 74 35]]
# allRight:  [[76.         99.         35.         73.         -1.65217391]
#  [75.         99.         35.         74.         -1.625     ]]
# lefy:  2.6 right: -1.583
# slope_rightP : -1.625
# slope_leftP : 3.0
# slope_right : -1.583
# slope_left : 2.6
# slope : 1.017
#
# modeL [ 3 18 72 35]
# modeR [78 98 35 74 -1]
# allLeft:  [[ 7 25 72 35]
#  [ 3 18 74 35]]
# allRight:  [[78.   98.   35.   74.   -1.95]]
# lefy:  2.467 right: -1.95
# slope_rightP : -1.583
# slope_leftP : 2.6
# slope_right : -1.95
# slope_left : 2.467
# slope : 0.517
#
# modeL [ 0 20 74 35]
# modeR [75 98 35 74 -1]
# allLeft:  [[ 0 20 74 35]
#  [ 9 21 74 35]]
# allRight:  [[76.         99.         35.         74.         -1.69565217]
#  [75.         98.         36.         74.         -1.65217391]]
# lefy:  1.95 right: -1.696
# slope_rightP : -1.95
# slope_leftP : 2.467
# slope_right : -1.696
# slope_left : 1.95
# slope : 0.254
#
# modeL [ 1 18 74 35]
# modeR [75 99 35 74 -1]
# allLeft:  [[ 3 19 74 35]
#  [ 1 18 74 35]
#  [ 7 22 74 35]]
# allRight:  [[75.         98.         36.         74.         -1.65217391]
#  [75.         99.         35.         74.         -1.625     ]
#  [77.         99.         35.         73.         -1.72727273]]
# lefy:  2.294 right: -1.625
# slope_rightP : -1.696
# slope_leftP : 1.95
# slope_right : -1.625
# slope_left : 2.294
# slope : 0.669
#
# modeL [ 0 19 74 35]
# modeR [78 98 35 74 -1]
# allLeft:  [[ 7 23 74 35]
#  [ 0 21 74 35]
#  [ 8 24 74 35]
#  [ 1 19 71 35]]
# allRight:  [[78.   98.   35.   74.   -1.95]]
# lefy:  2.053 right: -1.95
# slope_rightP : -1.625
# slope_leftP : 2.294
# slope_right : -1.95
# slope_left : 2.053
# slope : 0.103
#
# modeL [ 1 19 74 35]
# modeR [74 97 35 74 -1]
# allLeft:  [[ 6 25 74 35]
#  [ 1 21 74 35]
#  [ 1 19 70 35]
#  [ 6 23 72 35]]
# allRight:  [[76.         99.         35.         74.         -1.69565217]
#  [74.         97.         35.         74.         -1.69565217]]
# lefy:  2.167 right: -1.696
# slope_rightP : -1.95
# slope_leftP : 2.053
# slope_right : -1.696
# slope_left : 2.167
# slope : 0.471
#
# modeL [ 0 20 74 35]
# modeR [76 97 35 74 -1]
# allLeft:  [[ 0 20 74 35]
#  [ 7 23 74 35]
#  [ 6 22 73 35]]
# allRight:  [[79.         99.         35.         74.         -1.95      ]
#  [76.         97.         35.         74.         -1.85714286]]
# lefy:  1.95 right: -1.857
# slope_rightP : -1.696
# slope_leftP : 2.167
# slope_right : -1.857
# slope_left : 1.95
# slope : 0.093
#
# modeL [ 0 18 74 35]
# modeR [76 97 35 74 -1]
# allLeft:  [[ 1 19 74 35]
#  [ 8 23 74 35]
#  [ 0 18 74 35]
#  [ 6 22 74 35]]
# allRight:  [[78.         99.         35.         74.         -1.85714286]
#  [76.         97.         35.         74.         -1.85714286]]
# lefy:  2.167 right: -1.857
# slope_rightP : -1.857
# slope_leftP : 1.95
# slope_right : -1.857
# slope_left : 2.167
# slope : 0.31
#
# modeL [ 0 20 74 35]
# modeR [75 99 35 72 -1]
# allLeft:  [[ 0 20 74 35]
#  [ 8 22 74 35]]
# allRight:  [[75.         99.         36.         74.         -1.58333333]
#  [75.         99.         35.         72.         -1.54166667]]
# lefy:  1.95 right: -1.542
# slope_rightP : -1.857
# slope_leftP : 2.167
# slope_right : -1.542
# slope_left : 1.95
# slope : 0.408
#
# modeL [ 0 18 74 35]
# modeR [78 95 35 74 -2]
# allLeft:  [[ 7 23 72 35]
#  [ 1 20 74 35]
#  [ 8 24 74 35]
#  [ 0 18 74 35]]
# allRight:  [[77.         95.         35.         74.         -2.16666667]
#  [78.         98.         35.         70.         -1.75      ]
#  [78.         97.         36.         74.         -2.        ]]
# lefy:  2.167 right: -2.294
# slope_rightP : -1.542
# slope_leftP : 1.95
# slope_right : -2.294
# slope_left : 2.167
# slope : -0.127
# modeL [ 0 20 74 35]
# modeR [75 99 35 72 -1]
# allLeft:  [[ 7 25 72 35]
#  [ 1 21 74 35]
#  [ 0 20 74 35]]
# allRight:  [[75.         99.         36.         74.         -1.58333333]
#  [78.         99.         35.         72.         -1.76190476]]
# lefy:  1.95 right: -1.542
# slope_rightP : -2.294
# slope_leftP : 2.167
# slope_right : -1.542
# slope_left : 1.95
# slope : 0.408
#
# modeL [ 7 19 74 35]
# modeR [75 99 35 72 -1]
# allLeft:  [[ 0 22 74 35]
#  [ 7 24 74 35]
#  [ 1 19 70 35]
#  [ 7 23 72 35]]
# allRight:  [[75.         99.         35.         74.         -1.625     ]
#  [77.         99.         35.         72.         -1.68181818]]
# lefy:  3.25 right: -1.542
# slope_rightP : -1.542
# slope_leftP : 1.95
# slope_right : -1.542
# slope_left : 3.25
# slope : 1.708
#
# modeL [ 0 19 74 35]
# modeR [77 99 35 73 -1]
# allLeft:  [[ 8 24 74 35]
#  [ 7 22 74 35]
#  [ 1 19 70 35]
#  [ 0 20 74 35]]
# allRight:  [[78.         99.         35.         73.         -1.80952381]
#  [77.         99.         35.         74.         -1.77272727]]
# lefy:  2.053 right: -1.727
# slope_rightP : -1.542
# slope_leftP : 3.25
# slope_right : -1.727
# slope_left : 2.053
# slope : 0.326
#
# modeL [ 7 19 73 35]
# modeR [76 97 35 74 -2]
# allLeft:  [[ 7 25 73 35]
#  [ 0 19 73 35]
#  [ 2 20 74 35]
#  [ 7 23 71 35]]
# allRight:  [[78.         98.         35.         74.         -1.95      ]
#  [76.         97.         35.         74.         -1.85714286]
#  [80.         99.         35.         74.         -2.05263158]]
# lefy:  3.167 right: -1.857
# slope_rightP : -1.727
# slope_leftP : 2.053
# slope_right : -1.857
# slope_left : 3.167
# slope : 1.31
#
# modeL [ 2 18 74 35]
# modeR [76 98 35 73 -1]
# allLeft:  [[ 2 18 74 35]
#  [ 7 23 74 35]
#  [ 8 24 74 35]]
# allRight:  [[76.         98.         35.         74.         -1.77272727]
#  [78.         99.         35.         73.         -1.80952381]]
# lefy:  2.438 right: -1.727
# slope_rightP : -1.857
# slope_leftP : 3.167
# slope_right : -1.727
# slope_left : 2.438
# slope : 0.711
#
# modeL [ 0 20 74 35]
# modeR [77 99 35 74 -1]
# allLeft:  [[ 0 20 74 35]
#  [ 7 22 74 35]
#  [ 8 24 74 35]]
# allRight:  [[77.         99.         35.         74.         -1.77272727]]
# lefy:  1.95 right: -1.773
# slope_rightP : -1.727
# slope_leftP : 2.438
# slope_right : -1.773
# slope_left : 1.95
# slope : 0.177
#
# modeL [ 1 19 74 35]
# modeR [79 98 35 73 -2]
# allLeft:  [[ 8 25 74 35]
#  [ 1 19 74 35]
#  [ 7 23 74 35]
#  [ 2 20 74 35]]
# allRight:  [[79.         98.         35.         74.         -2.05263158]
#  [81.         98.         35.         73.         -2.23529412]]
# lefy:  2.167 right: -2.0
# slope_rightP : -1.773
# slope_leftP : 1.95
# slope_right : -2.0
# slope_left : 2.167
# slope : 0.167
#
# modeL [ 1 20 72 35]
# modeR [76 99 35 72 -1]
# allLeft:  [[ 8 23 74 35]
#  [ 1 20 72 35]]
# allRight:  [[76.         99.         37.         74.         -1.60869565]
#  [78.         99.         35.         72.         -1.76190476]]
# lefy:  1.947 right: -1.609
# slope_rightP : -2.0
# slope_leftP : 2.167
# slope_right : -1.609
# slope_left : 1.947
# slope : 0.338
#
# modeL [ 1 19 74 35]
# modeR [76 99 35 73 -1]
# allLeft:  [[ 6 22 74 35]
#  [ 1 21 74 35]
#  [ 8 24 74 35]
#  [ 1 19 71 35]]
# allRight:  [[76.         99.         35.         73.         -1.65217391]
#  [76.         99.         36.         74.         -1.65217391]]
# lefy:  2.167 right: -1.652
# slope_rightP : -1.609
# slope_leftP : 1.947
# slope_right : -1.652
# slope_left : 2.167
# slope : 0.515
#
# modeL [ 0 17 74 35]
# modeR [76 97 35 74 -1]
# allLeft:  [[ 0 17 74 35]
#  [ 1 19 74 35]
#  [ 7 21 74 35]
#  [ 6 20 74 36]]
# allRight:  [[76.         97.         35.         74.         -1.85714286]
#  [78.         98.         35.         74.         -1.95      ]]
# lefy:  2.294 right: -1.857
# slope_rightP : -1.652
# slope_leftP : 2.167
# slope_right : -1.857
# slope_left : 2.294
# slope : 0.437
#
# modeL [ 0 19 73 35]
# modeR [75 96 35 74 -1]
# allLeft:  [[ 6 25 73 35]
#  [ 0 21 73 35]
#  [ 7 24 68 35]
#  [ 0 19 72 35]]
# allRight:  [[79.         99.         35.         74.         -1.95      ]
#  [75.         96.         35.         74.         -1.85714286]]
# lefy:  2.0 right: -1.857
# slope_rightP : -1.857
# slope_leftP : 2.294
# slope_right : -1.857
# slope_left : 2.0
# slope : 0.143
#
# modeL [ 0 17 74 35]
# modeR [76 96 35 74 -1]
# allLeft:  [[ 6 21 74 35]
#  [ 1 19 74 35]
#  [ 7 24 74 35]
#  [ 0 17 74 35]]
# allRight:  [[78.   98.   35.   74.   -1.95]
#  [76.   96.   35.   74.   -1.95]]
# lefy:  2.294 right: -1.95
# slope_rightP : -1.857
# slope_leftP : 2.0
# slope_right : -1.95
# slope_left : 2.294
# slope : 0.344
#
# modeL [ 6 18 74 35]
# modeR [77 94 35 70 -2]
# allLeft:  [[ 0 18 73 35]
#  [ 6 23 72 35]
#  [ 6 24 74 35]
#  [ 1 19 74 35]]
# allRight:  [[78.         96.         35.         70.         -1.94444444]
#  [77.         94.         35.         70.         -2.05882353]]
# lefy:  3.25 right: -2.059
# slope_rightP : -1.95
# slope_leftP : 2.294
# slope_right : -2.059
# slope_left : 3.25
# slope : 1.191
#
# modeL [ 0 19 74 35]
# modeR [75 95 35 70 -1]
# allLeft:  [[ 0 19 72 35]
#  [ 7 22 74 35]
#  [ 0 19 74 36]]
# allRight:  [[77.   97.   35.   70.   -1.75]
#  [75.   95.   35.   72.   -1.85]]
# lefy:  2.053 right: -1.75
# slope_rightP : -2.059
# slope_leftP : 3.25
# slope_right : -1.75
# slope_left : 2.053
# slope : 0.303
#
# modeL [ 1 18 74 35]
# modeR [77 95 35 73 -2]
# allLeft:  [[ 1 18 74 35]
#  [ 7 22 74 35]
#  [ 8 23 74 35]
#  [ 2 19 74 35]]
# allRight:  [[79.         96.         35.         74.         -2.29411765]
#  [77.         95.         35.         73.         -2.11111111]
#  [81.         98.         35.         73.         -2.23529412]]
# lefy:  2.294 right: -2.111
# slope_rightP : -1.75
# slope_leftP : 2.053
# slope_right : -2.111
# slope_left : 2.294
# slope : 0.183
#
# modeL [ 1 18 74 35]
# modeR [75 99 35 72 -1]
# allLeft:  [[ 8 24 74 35]
#  [ 1 20 74 35]
#  [ 7 23 73 35]
#  [ 1 18 72 35]]
# allRight:  [[75.         99.         35.         73.         -1.58333333]
#  [80.         99.         35.         72.         -1.94736842]]
# lefy:  2.294 right: -1.542
# slope_rightP : -2.111
# slope_leftP : 2.294
# slope_right : -1.542
# slope_left : 2.294
# slope : 0.752
#
# modeL [ 1 20 71 35]
# modeR [76 99 35 74 -1]
# allLeft:  [[ 7 25 72 35]
#  [ 1 21 73 35]
#  [ 1 20 71 35]
#  [ 8 26 74 35]]
# allRight:  [[78.         99.         35.         74.         -1.85714286]
#  [76.         97.         35.         74.         -1.85714286]
#  [79.         99.         35.         72.         -1.85      ]]
# lefy:  1.895 right: -1.696
# slope_rightP : -1.542
# slope_leftP : 2.294
# slope_right : -1.696
# slope_left : 1.895
# slope : 0.199
#
# modeL [ 1 19 74 35]
# modeR [76 99 35 71 -1]
# allLeft:  [[ 1 19 74 35]
#  [ 2 21 74 35]
#  [10 24 73 35]
#  [ 7 23 74 35]]
# allRight:  [[76.         99.         35.         73.         -1.65217391]
#  [77.         99.         35.         71.         -1.63636364]]
# lefy:  2.167 right: -1.565
# slope_rightP : -1.696
# slope_leftP : 1.895
# slope_right : -1.565
# slope_left : 2.167
# slope : 0.602
#
# modeL [ 1 19 73 35]
# modeR [80 94 35 72 -2]
# allLeft:  [[ 1 19 74 35]
#  [ 7 27 73 35]]
# allRight:  [[80.         94.         35.         74.         -2.78571429]
#  [81.         99.         36.         72.         -2.        ]]
# lefy:  2.111 right: -2.643
# slope_rightP : -1.565
# slope_leftP : 2.167
# slope_right : -2.643
# slope_left : 2.111
# slope : -0.532
#
# modeL [ 2 22 69 35]
# modeR [75 99 35 72 -1]
# allLeft:  [[ 2 22 69 35]
#  [ 7 24 74 35]]
# allRight:  [[75.         99.         35.         74.         -1.625     ]
#  [77.         99.         35.         72.         -1.68181818]]
# lefy:  1.7 right: -1.542
# slope_rightP : -2.643
# slope_leftP : 2.111
# slope_right : -1.542
# slope_left : 1.7
# slope : 0.158
#
# modeL [ 1 19 74 35]
# modeR [76 99 35 72 -1]
# allLeft:  [[ 1 21 74 35]
#  [ 1 19 70 35]
#  [ 7 24 74 35]
#  [ 7 23 72 35]]
# allRight:  [[76.         99.         35.         74.         -1.69565217]
#  [77.         99.         35.         72.         -1.68181818]]
# lefy:  2.167 right: -1.609
# slope_rightP : -1.542
# slope_leftP : 1.7
# slope_right : -1.609
# slope_left : 2.167
# slope : 0.558
#
# modeL [ 0 20 74 35]
# modeR [74 97 35 73 -1]
# allLeft:  [[ 0 20 74 35]
#  [ 7 24 74 35]
#  [ 6 22 73 35]]
# allRight:  [[76.         99.         35.         73.         -1.65217391]
#  [74.         97.         35.         74.         -1.69565217]]
# lefy:  1.95 right: -1.652
# slope_rightP : -1.609
# slope_leftP : 2.167
# slope_right : -1.652
# slope_left : 1.95
# slope : 0.298
#
# modeL [ 0 18 71 35]
# modeR [74 98 35 70 -1]
# allLeft:  [[ 7 21 74 35]
#  [ 0 19 73 35]
#  [ 6 20 72 35]
#  [ 0 18 71 35]]
# allRight:  [[74.         98.         35.         73.         -1.58333333]
#  [76.         98.         35.         72.         -1.68181818]
#  [77.         98.         35.         70.         -1.66666667]]
# lefy:  2.0 right: -1.458
# slope_rightP : -1.652
# slope_leftP : 1.95
# slope_right : -1.458
# slope_left : 2.0
# slope : 0.542
#
# modeL [ 0 17 73 35]
# modeR [75 94 35 74 -2]
# allLeft:  [[ 7 21 74 35]
#  [ 5 20 73 35]
#  [ 0 17 73 35]]
# allRight:  [[77.         98.         35.         74.         -1.85714286]
#  [75.         94.         35.         74.         -2.05263158]]
# lefy:  2.235 right: -2.053
# slope_rightP : -1.458
# slope_leftP : 2.0
# slope_right : -2.053
# slope_left : 2.235
# slope : 0.182
# modeL [ 5 17 70 35]
# modeR [73 98 35 74 -2]
# allLeft:  [[ 5 22 74 35]
#  [ 0 17 72 35]
#  [ 5 20 70 35]]
# allRight:  [[77.     93.     35.     74.     -2.4375]
#  [78.     98.     35.     72.     -1.85  ]
#  [73.     98.     35.     74.     -1.56  ]]
# lefy:  2.917 right: -1.56
# slope_rightP : -2.053
# slope_leftP : 2.235
# slope_right : -1.56
# slope_left : 2.917
# slope : 1.357
#
# modeL [ 0 16 74 35]
# modeR [73 97 35 73 -1]
# allLeft:  [[ 0 18 71 35]
#  [ 5 20 74 35]
#  [ 6 21 74 35]
#  [ 0 16 69 35]]
# allRight:  [[74.         98.         35.         73.         -1.58333333]
#  [73.         97.         36.         74.         -1.58333333]]
# lefy:  2.438 right: -1.583
# slope_rightP : -1.56
# slope_leftP : 2.917
# slope_right : -1.583
# slope_left : 2.438
# slope : 0.855
#
# modeL [ 0 15 72 35]
# modeR [72 93 35 74 -1]
# allLeft:  [[ 4 21 73 35]
#  [ 0 15 72 35]]
# allRight:  [[73.         97.         35.         74.         -1.625     ]
#  [76.         98.         35.         74.         -1.77272727]
#  [72.         93.         35.         74.         -1.85714286]]
# lefy:  2.467 right: -1.857
# slope_rightP : -1.583
# slope_leftP : 2.438
# slope_right : -1.857
# slope_left : 2.467
# slope : 0.61
#
# modeL [ 0 14 73 35]
# modeR [72 96 35 74 -1]
# allLeft:  [[ 6 15 74 35]
#  [ 0 14 73 36]
#  [ 4 22 73 35]]
# allRight:  [[73.         97.         35.         74.         -1.625     ]
#  [76.         98.         35.         74.         -1.77272727]
#  [72.         96.         35.         74.         -1.625     ]]
# lefy:  2.714 right: -1.625
# slope_rightP : -1.857
# slope_leftP : 2.467
# slope_right : -1.625
# slope_left : 2.714
# slope : 1.089
#
# modeL [ 0 17 74 35]
# modeR [72 96 35 74 -1]
# allLeft:  [[ 5 21 74 35]
#  [ 4 19 74 35]
#  [ 0 17 71 35]]
# allRight:  [[75.         98.         35.         74.         -1.69565217]
#  [72.         96.         35.         74.         -1.625     ]]
# lefy:  2.294 right: -1.625
# slope_rightP : -1.625
# slope_leftP : 2.714
# slope_right : -1.625
# slope_left : 2.294
# slope : 0.669
#
# modeL [ 0 17 71 35]
# modeR [72 93 35 73 -1]
# allLeft:  [[ 4 19 74 35]
#  [ 5 20 73 35]
#  [ 0 17 71 35]]
# allRight:  [[73.         94.         35.         73.         -1.80952381]
#  [75.         96.         35.         69.         -1.61904762]
#  [72.         93.         35.         73.         -1.80952381]]
# lefy:  2.118 right: -1.81
# slope_rightP : -1.625
# slope_leftP : 2.294
# slope_right : -1.81
# slope_left : 2.118
# slope : 0.308
#
# modeL [ 0 14 74 35]
# modeR [76 91 35 74 -2]
# allLeft:  [[ 0 14 72 35]
#  [ 6 17 74 35]
#  [ 5 15 74 35]]
# allRight:  [[75.         92.         35.         74.         -2.29411765]
#  [76.         93.         36.         74.         -2.23529412]
#  [76.         96.         35.         73.         -1.9       ]
#  [74.         91.         35.         74.         -2.29411765]]
# lefy:  2.786 right: -2.6
# slope_rightP : -1.81
# slope_leftP : 2.118
# slope_right : -2.6
# slope_left : 2.786
# slope : 0.186
#
# modeL [ 0 15 74 35]
# modeR [72 93 35 74 -1]
# allLeft:  [[ 4 17 74 35]
#  [ 5 21 74 35]
#  [ 0 15 72 35]]
# allRight:  [[75.         98.         35.         74.         -1.69565217]
#  [73.         97.         35.         74.         -1.625     ]
#  [76.         96.         35.         68.         -1.65      ]
#  [72.         93.         35.         73.         -1.80952381]]
# lefy:  2.6 right: -1.857
# slope_rightP : -2.6
# slope_leftP : 2.786
# slope_right : -1.857
# slope_left : 2.6
# slope : 0.743
#
# modeL [ 0 14 70 35]
# modeR [73 90 35 74 -2]
# allLeft:  [[ 0 17 72 35]
#  [ 4 21 73 35]
#  [ 0 14 70 35]
#  [ 4 18 70 35]]
# allRight:  [[78.         92.         35.         74.         -2.78571429]
#  [73.         90.         35.         74.         -2.29411765]
#  [74.         97.         35.         73.         -1.65217391]]
# lefy:  2.5 right: -2.294
# slope_rightP : -1.857
# slope_leftP : 2.6
# slope_right : -2.294
# slope_left : 2.5
# slope : 0.206
#
# modeL [ 0 15 72 35]
# modeR [72 97 35 70 -1]
# allLeft:  [[ 4 21 74 35]
#  [ 0 15 73 35]
#  [ 1 16 72 35]]
# allRight:  [[76.         97.         35.         70.         -1.66666667]
#  [72.         97.         35.         74.         -1.56      ]
#  [74.         97.         35.         73.         -1.65217391]]
# lefy:  2.467 right: -1.4
# slope_rightP : -2.294
# slope_leftP : 2.5
# slope_right : -1.4
# slope_left : 2.467
# slope : 1.067
#
# modeL [ 0 15 74 35]
# modeR [73 98 35 74 -2]
# allLeft:  [[ 0 17 74 35]
#  [ 5 22 74 35]
#  [ 4 19 74 35]
#  [ 0 15 73 35]]
# allRight:  [[77.         98.         35.         74.         -1.85714286]
#  [73.         97.         35.         74.         -1.625     ]
#  [79.         98.         35.         73.         -2.        ]]
# lefy:  2.6 right: -1.56
# slope_rightP : -1.4
# slope_leftP : 2.467
# slope_right : -1.56
# slope_left : 2.6
# slope : 1.04
#
# modeL [ 0 19 70 35]
# modeR [73 98 35 74 -1]
# allLeft:  [[ 4 24 74 35]
#  [ 0 19 72 35]
#  [ 5 23 70 35]]
# allRight:  [[76.         98.         35.         74.         -1.77272727]
#  [74.         97.         35.         74.         -1.69565217]
#  [77.         98.         35.         72.         -1.76190476]
#  [73.         93.         35.         71.         -1.8       ]]
# lefy:  1.842 right: -1.56
# slope_rightP : -1.56
# slope_leftP : 2.6
# slope_right : -1.56
# slope_left : 1.842
# slope : 0.282
#
# modeL [ 0 16 74 35]
# modeR [73 98 35 74 -1]
# allLeft:  [[ 0 16 70 35]
#  [ 6 24 74 35]
#  [ 5 19 73 35]
#  [ 0 20 74 35]]
# allRight:  [[76.         98.         35.         74.         -1.77272727]
#  [73.         97.         35.         74.         -1.625     ]
#  [78.         98.         35.         72.         -1.85      ]]
# lefy:  2.438 right: -1.56
# slope_rightP : -1.56
# slope_leftP : 1.842
# slope_right : -1.56
# slope_left : 2.438
# slope : 0.878
#
# modeL [ 1 16 73 35]
# modeR [75 94 35 74 -2]
# allLeft:  [[ 1 16 74 35]
#  [ 6 20 74 35]
#  [ 8 22 73 35]
#  [ 2 17 73 35]]
# allRight:  [[77.         98.         35.         73.         -1.80952381]
#  [75.         94.         35.         74.         -2.05263158]
#  [78.         97.         38.         74.         -1.89473684]]
# lefy:  2.533 right: -2.053
# slope_rightP : -1.56
# slope_leftP : 2.438
# slope_right : -2.053
# slope_left : 2.533
# slope : 0.48
#
# modeL [ 0 18 73 35]
# modeR [75 96 35 74 -1]
# allLeft:  [[ 0 18 71 35]
#  [ 5 23 74 35]
#  [ 0 19 73 35]
#  [ 5 21 73 35]]
# allRight:  [[76.         99.         35.         74.         -1.69565217]
#  [75.         96.         35.         74.         -1.85714286]]
# lefy:  2.111 right: -1.857
# slope_rightP : -2.053
# slope_leftP : 2.533
# slope_right : -1.857
# slope_left : 2.111
# slope : 0.254
#
# modeL [ 1 16 74 35]
# modeR [74 94 35 68 -1]
# allLeft:  [[ 5 20 74 35]
#  [ 1 16 74 35]
#  [ 6 23 73 35]]
# allRight:  [[76.   96.   35.   68.   -1.65]
#  [74.   94.   35.   74.   -1.95]]
# lefy:  2.6 right: -1.65
# slope_rightP : -1.857
# slope_leftP : 2.111
# slope_right : -1.65
# slope_left : 2.6
# slope : 0.95
#
# modeL [ 0 16 70 35]
# modeR [75 91 35 74 -2]
# allLeft:  [[ 0 19 73 35]
#  [ 5 23 71 35]
#  [ 0 16 70 35]]
# allRight:  [[78.         92.         35.         74.         -2.78571429]
#  [79.         96.         35.         73.         -2.23529412]
#  [75.         91.         35.         74.         -2.4375    ]]
# lefy:  2.188 right: -2.438
# slope_rightP : -1.65
# slope_leftP : 2.6
# slope_right : -2.438
# slope_left : 2.188
# slope : -0.25
#
# modeL [ 5 15 74 35]
# modeR [76 93 35 74 -2]
# allLeft:  [[ 1 16 74 36]
#  [ 5 23 74 35]
#  [ 0 15 74 35]
#  [ 5 22 73 35]]
# allRight:  [[77.         94.         35.         74.         -2.29411765]
#  [78.         98.         35.         74.         -1.95      ]
#  [76.         93.         35.         74.         -2.29411765]]
# lefy:  3.9 right: -2.294
# slope_rightP : -2.438
# slope_leftP : 2.188
# slope_right : -2.294
# slope_left : 3.9
# slope : 1.606
#
# modeL [ 0 17 74 35]
# modeR [73 98 35 73 -2]
# allLeft:  [[ 5 22 74 35]
#  [ 0 17 71 35]
#  [ 0 20 74 35]
#  [ 5 21 73 35]]
# allRight:  [[79.   98.   35.   73.   -2.  ]
#  [73.   98.   35.   74.   -1.56]]
# lefy:  2.294 right: -1.52
# slope_rightP : -2.294
# slope_leftP : 3.9
# slope_right : -1.52
# slope_left : 2.294
# slope : 0.774
#
# modeL [ 0 18 74 35]
# modeR [73 98 35 72 -1]
# allLeft:  [[ 0 19 73 35]
#  [ 5 21 74 35]
#  [ 1 97 38 35]
#  [ 0 18 70 35]
#  [ 7 22 74 35]]
# allRight:  [[73.         98.         35.         73.         -1.52      ]
#  [76.         98.         36.         72.         -1.63636364]
#  [74.         97.         37.         74.         -1.60869565]]
# lefy:  2.167 right: -1.48
# slope_rightP : -1.52
# slope_leftP : 2.294
# slope_right : -1.48
# slope_left : 2.167
# slope : 0.687
# modeL [ 0 17 74 35]
# modeR [73 96 35 73 -1]
# allLeft:  [[ 6 20 74 35]
#  [ 0 17 74 35]
#  [ 0 97 39 36]]
# allRight:  [[75.         98.         35.         73.         -1.65217391]
#  [73.         96.         35.         74.         -1.69565217]]
# lefy:  2.294 right: -1.652
# slope_rightP : -1.48
# slope_leftP : 2.167
# slope_right : -1.652
# slope_left : 2.294
# slope : 0.642
#
# modeL [ 0 17 35 35]
# modeR [73 97 35 74 -1]
# allLeft:  [[ 6 20 74 35]
#  [ 0 19 73 35]
#  [ 0 17 71 35]
#  [ 2 96 35 36]]
# allRight:  [[78.    98.    35.    74.    -1.95 ]
#  [73.    97.    35.    74.    -1.625]]
# lefy:  0.0 right: -1.625
# slope_rightP : -1.652
# slope_leftP : 2.294
# slope_right : -1.625
# slope_left : 0.0
# slope : -1.625
#
# modeL [ 0 18 74 35]
# modeR [77 93 35 74 -2]
# allLeft:  [[ 1 97 36 37]
#  [ 0 18 70 35]
#  [ 5 22 74 35]
#  [ 0 19 74 35]]
# allRight:  [[77.         93.         35.         74.         -2.4375    ]
#  [79.         97.         35.         74.         -2.16666667]]
# lefy:  2.167 right: -2.438
# slope_rightP : -1.625
# slope_leftP : 0.0
# slope_right : -2.438
# slope_left : 2.167
# slope : -0.271
#
# modeL [ 0 16 74 38]
# modeR [80 97 38 74 -2]
# allLeft:  [[ 0 96 37 36]
#  [ 1 97 36 38]
#  [ 0 17 74 38]
#  [ 5 19 74 38]
#  [ 6 20 72 38]
#  [ 0 16 73 38]]
# allRight:  [[80.         97.         38.         74.         -2.11764706]]
# lefy:  2.25 right: -2.118
# slope_rightP : -2.438
# slope_leftP : 2.167
# slope_right : -2.118
# slope_left : 2.25
# slope : 0.132
#
# modeL [ 0 98 37 35]
# modeR [73 95 35 74 -1]
# allLeft:  [[ 0 98 38 40]
#  [ 5 21 72 35]
#  [ 0 99 37 36]
#  [ 0 98 39 37]
#  [ 1 16 74 35]]
# allRight:  [[73.         95.         35.         74.         -1.77272727]
#  [77.         97.         35.         74.         -1.95      ]]
# lefy:  0.02 right: -1.773
# slope_rightP : -2.118
# slope_leftP : 2.25
# slope_right : -1.773
# slope_left : 0.02
# slope : -1.753
#
# modeL [ 0 15 72 35]
# allLeft:  [[ 4 23 72 35]
#  [ 0 15 74 35]]
# allRight:  []
# lefy:  2.467 right: -1.773
# slope_rightP : -1.773
# slope_leftP : 0.02
# slope_right : -1.773
# slope_left : 2.467
# slope : 0.694
#
# modeL [ 4 16 71 35]
# modeR [74 96 35 72 -1]
# allLeft:  [[ 4 20 72 35]
#  [ 0 16 71 35]
#  [ 4 21 74 35]]
# allRight:  [[74.         96.         35.         72.         -1.68181818]]
# lefy:  3.0 right: -1.682
# slope_rightP : -1.773
# slope_leftP : 2.467
# slope_right : -1.682
# slope_left : 3.0
# slope : 1.318
#
# modeL [ 0 16 74 35]
# modeR [74 93 35 74 -2]
# allLeft:  [[ 4 19 74 35]
#  [ 0 16 72 35]
#  [ 5 21 74 35]]
# allRight:  [[74.         93.         35.         74.         -2.05263158]
#  [77.         97.         35.         73.         -1.9       ]
#  [76.         96.         35.         74.         -1.95      ]]
# lefy:  2.438 right: -2.053
# slope_rightP : -1.682
# slope_leftP : 3.0
# slope_right : -2.053
# slope_left : 2.438
# slope : 0.385
#
# modeL [ 0 18 74 35]
# modeR [71 91 35 74 -2]
# allLeft:  [[ 0 99 43 37]
#  [ 3 18 74 35]
#  [ 5 18 74 36]
#  [ 0 15 72 35]]
# allRight:  [[75.         97.         35.         74.         -1.77272727]
#  [74.         92.         35.         73.         -2.11111111]
#  [71.         91.         35.         74.         -1.95      ]]
# lefy:  2.167 right: -1.95
# slope_rightP : -2.053
# slope_leftP : 2.438
# slope_right : -1.95
# slope_left : 2.167
# slope : 0.217
#
# modeL [ 3 14 71 35]
# modeR [71 97 35 74 -1]
# allLeft:  [[ 3 20 74 35]
#  [ 3 19 73 35]
#  [ 1 14 71 35]]
# allRight:  [[73.    97.    35.    74.    -1.625]
#  [77.    97.    35.    72.    -1.85 ]
#  [71.    91.    35.    74.    -1.95 ]]
# lefy:  3.273 right: -1.5
# slope_rightP : -1.95
# slope_leftP : 2.167
# slope_right : -1.5
# slope_left : 3.273
# slope : 1.773
#
# modeL [ 0 15 74 35]
# modeR [73 97 35 72 -1]
# allLeft:  [[ 4 18 74 35]
#  [ 3 16 74 35]
#  [ 0 15 70 35]]
# allRight:  [[73.         97.         35.         74.         -1.625     ]
#  [75.         97.         35.         72.         -1.68181818]]
# lefy:  2.6 right: -1.542
# slope_rightP : -1.5
# slope_leftP : 3.273
# slope_right : -1.542
# slope_left : 2.6
# slope : 1.058
#
# modeL [ 3 14 69 35]
# modeR [72 92 35 74 -1]
# allLeft:  [[ 3 19 74 35]
#  [ 3 17 73 35]
#  [ 0 14 69 35]]
# allRight:  [[77.         97.         35.         74.         -1.95      ]
#  [72.         96.         35.         74.         -1.625     ]
#  [74.         92.         39.         74.         -1.94444444]]
# lefy:  3.091 right: -1.95
# slope_rightP : -1.542
# slope_leftP : 2.6
# slope_right : -1.95
# slope_left : 3.091
# slope : 1.141
#
# modeL [ 2 15 74 35]
# modeR [71 97 35 73 -1]
# allLeft:  [[ 4 16 74 35]
#  [ 2 15 74 35]]
# allRight:  [[71.         97.         35.         74.         -1.5       ]
#  [74.         97.         35.         73.         -1.65217391]]
# lefy:  3.0 right: -1.462
# slope_rightP : -1.95
# slope_leftP : 3.091
# slope_right : -1.462
# slope_left : 3.0
# slope : 1.538
#
# modeL [ 4 15 70 35]
# modeR [70 96 35 70 -1]
# allLeft:  [[ 4 19 74 35]
#  [ 4 17 72 35]
#  [ 0 15 70 35]]
# allRight:  [[70.         97.         35.         74.         -1.44444444]
#  [75.         96.         35.         70.         -1.66666667]]
# lefy:  3.182 right: -1.346
# slope_rightP : -1.462
# slope_leftP : 3.0
# slope_right : -1.346
# slope_left : 3.182
# slope : 1.836
#
# modeL [ 2 14 74 35]
# modeR [71 96 35 74 -1]
# allLeft:  [[ 2 18 74 35]
#  [ 2 16 73 35]
#  [ 4 20 74 35]
#  [ 0 14 69 35]]
# allRight:  [[71.         96.         35.         74.         -1.56      ]
#  [73.         97.         35.         74.         -1.625     ]
#  [74.         96.         35.         71.         -1.63636364]]
# lefy:  3.25 right: -1.56
# slope_rightP : -1.346
# slope_leftP : 3.182
# slope_right : -1.56
# slope_left : 3.25
# slope : 1.69
#
# modeL [ 1 14 71 35]
# modeR [72 92 35 73 -1]
# allLeft:  [[ 6 15 72 35]
#  [ 1 14 71 35]]
# allRight:  [[76.         97.         35.         74.         -1.85714286]
#  [73.         94.         35.         73.         -1.80952381]
#  [72.         92.         35.         73.         -1.9       ]]
# lefy:  2.769 right: -1.9
# slope_rightP : -1.56
# slope_leftP : 3.25
# slope_right : -1.9
# slope_left : 2.769
# slope : 0.869
#
# modeL [ 1 14 74 35]
# modeR [72 95 35 74 -2]
# allLeft:  [[ 3 16 74 35]
#  [ 1 14 71 35]
#  [ 4 17 74 35]]
# allRight:  [[79.         97.         35.         74.         -2.16666667]
#  [72.         95.         35.         74.         -1.69565217]
#  [77.         96.         35.         74.         -2.05263158]]
# lefy:  3.0 right: -1.696
# slope_rightP : -1.9
# slope_leftP : 2.769
# slope_right : -1.696
# slope_left : 3.0
# slope : 1.304
#
# modeL [ 0 14 74 35]
# modeR [74 93 35 74 -2]
# allLeft:  [[ 4 19 74 35]
#  [ 3 16 74 35]
#  [ 0 14 69 35]]
# allRight:  [[77.         98.         35.         74.         -1.85714286]
#  [76.         94.         35.         74.         -2.16666667]
#  [74.         93.         35.         74.         -2.05263158]]
# lefy:  2.786 right: -2.053
# slope_rightP : -1.696
# slope_leftP : 3.0
# slope_right : -2.053
# slope_left : 2.786
# slope : 0.733
#
# modeL [ 3 14 71 35]
# modeR [74 95 35 70 -1]
# allLeft:  [[ 3 21 74 35]
#  [ 0 14 71 35]
#  [ 3 19 73 35]]
# allRight:  [[74.         95.         35.         73.         -1.80952381]
#  [77.         96.         35.         71.         -1.89473684]
#  [79.         97.         35.         70.         -1.94444444]]
# lefy:  3.273 right: -1.667
# slope_rightP : -2.053
# slope_leftP : 2.786
# slope_right : -1.667
# slope_left : 3.273
# slope : 1.606
#
# modeL [ 0 17 70 35]
# modeR [75 93 35 74 -2]
# allLeft:  [[ 0 17 72 35]
#  [ 4 18 70 35]
#  [ 3 21 74 35]]
# allRight:  [[80.         97.         35.         74.         -2.29411765]
#  [78.         94.         35.         74.         -2.4375    ]
#  [75.         93.         35.         74.         -2.16666667]]
# lefy:  2.059 right: -2.167
# slope_rightP : -1.667
# slope_leftP : 3.273
# slope_right : -2.167
# slope_left : 2.059
# slope : -0.108
#
# modeL [ 3 15 74 35]
# modeR [74 98 35 72 -1]
# allLeft:  [[ 5 15 74 35]
#  [ 3 22 74 35]]
# allRight:  [[75.         98.         35.         73.         -1.65217391]
#  [77.         98.         35.         72.         -1.76190476]
#  [74.         93.         35.         72.         -1.94736842]]
# lefy:  3.25 right: -1.542
# slope_rightP : -2.167
# slope_leftP : 2.059
# slope_right : -1.542
# slope_left : 3.25
# slope : 1.708
#
# modeL [ 3 14 74 35]
# modeR [73 98 35 72 -1]
# allLeft:  [[ 5 14 74 36]
#  [ 3 21 74 35]]
# allRight:  [[75.         98.         35.         73.         -1.65217391]
#  [73.         97.         35.         74.         -1.625     ]
#  [77.         98.         35.         72.         -1.76190476]]
# lefy:  3.545 right: -1.48
# slope_rightP : -1.542
# slope_leftP : 3.25
# slope_right : -1.48
# slope_left : 3.545
# slope : 2
#
# modeL [ 0 14 74 35]
# modeR [73 92 35 73 -2]
# allLeft:  [[ 4 18 74 35]
#  [ 0 14 69 35]
#  [ 0 15 71 35]
#  [ 5 20 74 35]]
# allRight:  [[73.   98.   35.   73.   -1.52]
#  [77.   92.   35.   74.   -2.6 ]]
# lefy:  2.786 right: -2.0
# slope_rightP : -1.48
# slope_leftP : 3.545
# slope_right : -2.0
# slope_left : 2.786
# slope : 0.786
#
# modeL [ 0 15 74 35]
# modeR [75 92 35 74 -1]
# allLeft:  [[ 2 19 74 35]
#  [ 3 20 74 35]
#  [ 0 15 70 35]]
# allRight:  [[77.         97.         35.         74.         -1.95      ]
#  [75.         92.         35.         74.         -2.29411765]
#  [78.         98.         35.         74.         -1.95      ]]
# lefy:  2.6 right: -2.294
# slope_rightP : -2.0
# slope_leftP : 2.786
# slope_right : -2.294
# slope_left : 2.6
# slope : 0.306
# modeL [ 3 16 74 35]
# modeR [76 93 35 74 -2]
# allLeft:  [[ 4 18 74 35]
#  [ 3 16 74 35]]
# allRight:  [[77.         97.         35.         74.         -1.95      ]
#  [76.         93.         35.         74.         -2.29411765]]
# lefy:  3.0 right: -2.294
# slope_rightP : -2.294
# slope_leftP : 2.6
# slope_right : -2.294
# slope_left : 3.0
# slope : 0.706
#
# modeL [ 3 14 74 35]
# modeR [72 92 35 74 -1]
# allLeft:  [[ 3 14 74 35]]
# allRight:  [[73.         92.         35.         72.         -1.94736842]
#  [79.         97.         35.         74.         -2.16666667]
#  [76.         96.         35.         74.         -1.95      ]
#  [72.         92.         35.         74.         -1.95      ]]
# lefy:  3.545 right: -1.95
# slope_rightP : -2.294
# slope_leftP : 3.0
# slope_right : -1.95
# slope_left : 3.545
# slope : 1.595
#
# modeL [ 3 15 74 35]
# modeR [72 97 35 73 -1]
# allLeft:  [[ 3 15 74 35]]
# allRight:  [[72.         93.         35.         74.         -1.85714286]
#  [75.         97.         35.         74.         -1.77272727]
#  [77.         97.         35.         73.         -1.9       ]
#  [74.         94.         35.         73.         -1.9       ]]
# lefy:  3.25 right: -1.52
# slope_rightP : -1.95
# slope_leftP : 3.545
# slope_right : -1.52
# slope_left : 3.25
# slope : 1.73
#
# modeL [ 1 15 74 35]
# modeR [70 94 35 73 -1]
# allLeft:  [[ 2 17 74 35]
#  [ 1 15 74 35]]
# allRight:  [[73.         94.         35.         70.         -1.66666667]
#  [72.         93.         35.         73.         -1.80952381]
#  [75.         94.         35.         67.         -1.68421053]
#  [70.         91.         35.         73.         -1.80952381]]
# lefy:  2.786 right: -1.583
# slope_rightP : -1.52
# slope_leftP : 3.25
# slope_right : -1.583
# slope_left : 2.786
# slope : 1.203
#
# modeL [ 1 15 72 35]
# modeR [71 95 35 70 -2]
# allLeft:  [[ 2 17 74 35]
#  [ 1 15 72 35]]
# allRight:  [[72.         95.         35.         72.         -1.60869565]
#  [71.         89.         35.         74.         -2.16666667]
#  [75.         95.         35.         70.         -1.75      ]]
# lefy:  2.643 right: -1.458
# slope_rightP : -1.583
# slope_leftP : 2.786
# slope_right : -1.458
# slope_left : 2.643
# slope : 1.185
#
# modeL [ 0 17 73 35]
# modeR [68 90 35 74 -1]
# allLeft:  [[ 0 17 73 35]]
# allRight:  [[73.         95.         35.         71.         -1.63636364]
#  [70.         96.         35.         74.         -1.5       ]
#  [68.         90.         35.         74.         -1.77272727]]
# lefy:  2.235 right: -1.773
# slope_rightP : -1.458
# slope_leftP : 2.643
# slope_right : -1.773
# slope_left : 2.235
# slope : 0.462
#
# modeL [ 1 12 74 35]
# modeR [70 89 35 73 -1]
# allLeft:  [[ 2 14 74 35]
#  [ 1 12 74 35]]
# allRight:  [[70.         94.         35.         74.         -1.625     ]
#  [73.         95.         35.         73.         -1.72727273]
#  [70.         89.         36.         73.         -1.94736842]]
# lefy:  3.545 right: -2.0
# slope_rightP : -1.773
# slope_leftP : 2.235
# slope_right : -2.0
# slope_left : 3.545
# slope : 1.545
#
# modeL [ 1 12 74 35]
# modeR [67 94 35 74 -1]
# allLeft:  [[ 1 12 74 35]
#  [ 2 16 74 35]]
# allRight:  [[67.         94.         35.         74.         -1.44444444]
#  [73.         95.         35.         74.         -1.77272727]]
# lefy:  3.545 right: -1.444
# slope_rightP : -2.0
# slope_leftP : 3.545
# slope_right : -1.444
# slope_left : 3.545
# slope : 2
#
# modeL [ 0 13 73 35]
# modeR [69 89 35 74 -1]
# allLeft:  [[ 1 16 74 35]
#  [ 0 13 73 35]]
# allRight:  [[69.         92.         35.         74.         -1.69565217]
#  [73.         95.         35.         74.         -1.77272727]
#  [69.         89.         36.         72.         -1.8       ]]
# lefy:  2.923 right: -1.95
# slope_rightP : -1.444
# slope_leftP : 3.545
# slope_right : -1.95
# slope_left : 2.923
# slope : 0.973
#
# modeL [ 0 13 73 35]
# modeR [70 95 35 74 -2]
# allLeft:  [[ 0 17 74 35]
#  [ 0 13 73 35]]
# allRight:  [[72.         90.         35.         74.         -2.16666667]
#  [73.         95.         35.         74.         -1.77272727]
#  [70.         89.         35.         74.         -2.05263158]
#  [74.         95.         35.         72.         -1.76190476]]
# lefy:  2.923 right: -1.56
# slope_rightP : -1.95
# slope_leftP : 2.923
# slope_right : -1.56
# slope_left : 2.923
# slope : 1.363
#
# modeL [ 0 14 74 35]
# modeR [70 90 35 70 -1]
# allLeft:  [[ 1 17 74 35]
#  [ 0 14 74 35]]
# allRight:  [[72.         94.         35.         70.         -1.59090909]
#  [70.         90.         36.         72.         -1.8       ]]
# lefy:  2.786 right: -1.75
# slope_rightP : -1.56
# slope_leftP : 2.923
# slope_right : -1.75
# slope_left : 2.786
# slope : 1.036
#
# modeL [ 1 13 74 35]
# modeR [71 90 35 74 -2]
# allLeft:  [[ 1 13 74 35]
#  [ 2 15 74 35]]
# allRight:  [[77.         95.         37.         74.         -2.05555556]
#  [71.         90.         35.         74.         -2.05263158]
#  [75.         94.         35.         74.         -2.05263158]
#  [73.         90.         35.         73.         -2.23529412]]
# lefy:  3.25 right: -2.053
# slope_rightP : -1.75
# slope_leftP : 2.786
# slope_right : -2.053
# slope_left : 3.25
# slope : 1.197
#
# modeL [ 0 15 74 35]
# modeR [72 90 35 74 -2]
# allLeft:  [[ 0 17 74 35]
#  [ 1 19 74 35]
#  [ 0 15 72 35]]
# allRight:  [[75.         96.         35.         74.         -1.85714286]
#  [72.         90.         35.         73.         -2.11111111]
#  [73.         95.         35.         74.         -1.77272727]]
# lefy:  2.6 right: -2.167
# slope_rightP : -2.053
# slope_leftP : 3.25
# slope_right : -2.167
# slope_left : 2.6
# slope : 0.433
#
# modeL [ 0 19 73 35]
# modeR [71 95 35 70 -1]
# allLeft:  [[ 0 19 73 35]]
# allRight:  [[73.         95.         35.         70.         -1.59090909]
#  [71.         95.         35.         74.         -1.625     ]]
# lefy:  2.0 right: -1.458
# slope_rightP : -2.167
# slope_leftP : 2.6
# slope_right : -1.458
# slope_left : 2.0
# slope : 0.542
#
# modeL [ 0 18 69 35]
# modeR [72 95 35 74 -1]
# allLeft:  [[ 0 19 73 35]
#  [ 1 18 69 35]]
# allRight:  [[75.         96.         35.         74.         -1.85714286]
#  [72.         95.         35.         74.         -1.69565217]]
# lefy:  1.889 right: -1.696
# slope_rightP : -1.458
# slope_leftP : 2.0
# slope_right : -1.696
# slope_left : 1.889
# slope : 0.193
#
# modeL [ 0 15 74 35]
# modeR [72 94 35 74 -1]
# allLeft:  [[ 0 15 74 35]
#  [ 1 16 74 35]]
# allRight:  [[72.         94.         35.         74.         -1.77272727]
#  [76.         96.         35.         74.         -1.95      ]]
# lefy:  2.6 right: -1.773
# slope_rightP : -1.696
# slope_leftP : 1.889
# slope_right : -1.773
# slope_left : 2.6
# slope : 0.827
#
# modeL [ 0 14 74 35]
# modeR [74 90 35 74 -2]
# allLeft:  [[ 1 19 74 35]
#  [ 0 14 74 35]]
# allRight:  [[76.         95.         35.         74.         -2.05263158]
#  [74.         90.         36.         74.         -2.375     ]]
# lefy:  2.786 right: -2.438
# slope_rightP : -1.773
# slope_leftP : 2.6
# slope_right : -2.438
# slope_left : 2.786
# slope : 0.348
#
# modeL [ 1 19 73 35]
# modeR [77 95 35 74 -2]
# allLeft:  [[ 1 19 73 35]]
# allRight:  [[77.         95.         35.         74.         -2.16666667]]
# lefy:  2.111 right: -2.167
# slope_rightP : -2.438
# slope_leftP : 2.786
# slope_right : -2.167
# slope_left : 2.111
# slope : -0.056
#
# modeL [ 0 20 74 35]
# allLeft:  [[ 0 20 74 35]]
# allRight:  []
# lefy:  1.95 right: -2.167
# slope_rightP : -2.167
# slope_leftP : 2.111
# slope_right : -2.167
# slope_left : 1.95
# slope : -0.217
#
# modeL [ 0 14 74 35]
# allLeft:  [[ 0 14 73 35]
#  [ 1 16 74 35]
#  [ 2 17 74 35]]
# allRight:  []
# lefy:  2.786 right: -2.167
# slope_rightP : -2.167
# slope_leftP : 1.95
# slope_right : -2.167
# slope_left : 2.786
# slope : 0.619
#
# modeL [ 0 18 73 35]
# modeR [76 95 35 72 -1]
# allLeft:  [[ 0 18 73 35]]
# allRight:  [[76.         95.         35.         72.         -1.94736842]]
# lefy:  2.111 right: -1.947
# slope_rightP : -2.167
# slope_leftP : 2.786
# slope_right : -1.947
# slope_left : 2.111
# slope : 0.164
#
# modeL [ 0 11 74 35]
# modeR [76 88 35 73 -3]
# allLeft:  [[ 0 11 74 37]
#  [ 2 14 74 35]]
# allRight:  [[76.         88.         35.         74.         -3.25      ]
#  [78.         95.         35.         73.         -2.23529412]]
# lefy:  3.545 right: -3.167
# slope_rightP : -1.947
# slope_leftP : 2.111
# slope_right : -3.167
# slope_left : 3.545
# slope : 0.378
#
# modeL [ 1 12 74 35]
# modeR [77 88 35 74 -3]
# allLeft:  [[ 1 12 74 35]
#  [ 2 17 74 35]]
# allRight:  [[77.         88.         35.         74.         -3.54545455]
#  [78.         93.         36.         74.         -2.53333333]]
# lefy:  3.545 right: -3.545
# slope_rightP : -3.167
# slope_leftP : 3.545
# slope_right : -3.545
# slope_left : 3.545
# slope : 0.0
#
# modeL [ 0 14 74 35]
# modeR [77 96 35 74 -2]
# allLeft:  [[ 0 14 74 35]
#  [ 1 16 74 35]]
# allRight:  [[77.         96.         35.         74.         -2.05263158]]
# lefy:  2.786 right: -2.053
# slope_rightP : -3.545
# slope_leftP : 3.545
# slope_right : -2.053
# slope_left : 2.786
# slope : 0.733
#
# modeL [ 0 19 73 35]
# modeR [79 95 35 74 -2]
# allLeft:  [[ 0 19 73 35]]
# allRight:  [[79.     95.     35.     74.     -2.4375]]
# lefy:  2.0 right: -2.438
# slope_rightP : -2.053
# slope_leftP : 2.786
# slope_right : -2.438
# slope_left : 2.0
# slope : -0.438
#
# modeL [ 1 15 74 35]
# allLeft:  [[ 3 18 74 35]
#  [ 1 15 72 35]
#  [ 1 17 74 35]]
# allRight:  []
# lefy:  2.786 right: -2.438
# slope_rightP : -2.438
# slope_leftP : 2.0
# slope_right : -2.438
# slope_left : 2.786
# slope : 0.348
#
# modeL [ 1 15 74 35]
# allLeft:  [[ 3 16 74 35]
#  [ 1 15 74 35]]
# allRight:  []
# lefy:  2.786 right: -2.438
# slope_rightP : -2.438
# slope_leftP : 2.786
# slope_right : -2.438
# slope_left : 2.786
# slope : 0.348
#
# modeL [ 1 19 69 35]
# allLeft:  [[ 1 21 73 35]
#  [ 2 19 69 35]]
# allRight:  []
# lefy:  1.889 right: -2.438
# slope_rightP : -2.438
# slope_leftP : 2.786
# slope_right : -2.438
# slope_left : 1.889
# slope : -0.549
#
# modeL [ 1 17 74 35]
# allLeft:  [[ 1 19 74 35]
#  [ 2 20 74 35]
#  [ 1 17 72 35]]
# allRight:  []
# lefy:  2.438 right: -2.438
# slope_rightP : -2.438
# slope_leftP : 1.889
# slope_right : -2.438
# slope_left : 2.438
# slope : 0.0
#
# modeL [ 1 15 73 35]
# allLeft:  [[ 2 17 74 35]
#  [ 1 15 73 35]]
# allRight:  []
# lefy:  2.714 right: -2.438
# slope_rightP : -2.438
# slope_leftP : 2.438
# slope_right : -2.438
# slope_left : 2.714
# slope : 0.276
#
# modeL [ 1 18 72 35]
# allLeft:  [[ 1 20 74 35]
#  [ 1 18 72 35]]
# allRight:  []
# lefy:  2.176 right: -2.438
# slope_rightP : -2.438
# slope_leftP : 2.714
# slope_right : -2.438
# slope_left : 2.176
# slope : -0.262
#
# modeL [ 1 17 74 35]
# modeR [87 95 39 74 -4]
# allLeft:  [[ 1 17 74 35]
#  [ 3 19 74 35]]
# allRight:  [[87.    95.    39.    74.    -4.375]]
# lefy:  2.438 right: -4.375
# slope_rightP : -2.438
# slope_leftP : 2.176
# slope_right : -4.375
# slope_left : 2.438
# slope : -1.937
#
# modeL [ 0 19 72 35]
# allLeft:  [[ 0 19 72 35]
#  [ 1 20 74 35]]
# allRight:  []
# lefy:  1.947 right: -4.375
# slope_rightP : -4.375
# slope_leftP : 2.438
# slope_right : -4.375
# slope_left : 1.947
# slope : -2
#
# modeL [ 0 10 74 35]
# allLeft:  [[ 2 14 74 35]
#  [ 0 10 74 40]]
# allRight:  []
# lefy:  3.9 right: -4.375
# slope_rightP : -4.375
# slope_leftP : 1.947
# slope_right : -4.375
# slope_left : 3.9
# slope : -0.475
#
# modeL [ 0 14 74 35]
# allLeft:  [[ 1 16 74 35]
#  [ 0 14 74 35]]
# allRight:  []
# lefy:  2.786 right: -4.375
# slope_rightP : -4.375
# slope_leftP : 3.9
# slope_right : -4.375
# slope_left : 2.786
# slope : -1.589
#
# modeL [ 0 15 74 35]
# allLeft:  [[ 2 17 74 35]
#  [ 0 15 74 35]]
# allRight:  []
# lefy:  2.6 right: -4.375
# slope_rightP : -4.375
# slope_leftP : 2.786
# slope_right : -4.375
# slope_left : 2.6
# slope : -1.775
#
# modeL [ 0 15 74 35]
# allLeft:  [[ 1 19 74 35]
#  [ 0 17 74 35]
#  [ 0 15 72 35]]
# allRight:  []
# lefy:  2.6 right: -4.375
# slope_rightP : -4.375
# slope_leftP : 2.6
# slope_right : -4.375
# slope_left : 2.6
# slope : -1.775
#
# modeL [ 1 10 74 35]
# allLeft:  [[ 0 10 74 40]
#  [ 1 20 74 35]
#  [ 1 15 73 35]]
# allRight:  []
# lefy:  4.333 right: -4.375
# slope_rightP : -4.375
# slope_leftP : 2.6
# slope_right : -4.375
# slope_left : 4.333
# slope : -0.042
#
# modeL [ 0 18 69 35]
# allLeft:  [[ 0 19 73 35]
#  [ 1 18 69 35]]
# allRight:  []
# lefy:  1.889 right: -4.375
# slope_rightP : -4.375
# slope_leftP : 4.333
# slope_right : -4.375
# slope_left : 1.889
# slope : -2
#
# modeL [ 0 15 74 35]
# allLeft:  [[ 1 19 74 35]
#  [ 0 17 74 35]
#  [ 0 15 73 35]]
# allRight:  []
# lefy:  2.6 right: -4.375
# slope_rightP : -4.375
# slope_leftP : 1.889
# slope_right : -4.375
# slope_left : 2.6
# slope : -1.775
#
# modeL [ 1 14 74 35]
# allLeft:  [[ 1 17 74 35]
#  [ 1 16 73 36]
#  [ 0 14 74 35]]
# allRight:  []
# lefy:  3.0 right: -4.375
# slope_rightP : -4.375
# slope_leftP : 2.6
# slope_right : -4.375
# slope_left : 3.0
# slope : -1.375
#
# modeL [ 0 14 74 35]
# allLeft:  [[ 1 16 74 35]
#  [ 0 14 74 35]]
# allRight:  []
# lefy:  2.786 right: -4.375
# slope_rightP : -4.375
# slope_leftP : 3.0
# slope_right : -4.375
# slope_left : 2.786
# slope : -1.589
#
# modeL [ 0 16 74 35]
# ...
#
# modeL [ 8 27 74 35]
# modeR [79 98 35 71 -2]
# allLeft:  [[17 31 74 35]
#  [ 8 27 73 35]
#  [16 30 74 35]]
# allRight:  [[82.         99.         35.         71.         -2.11764706]
#  [79.         98.         35.         72.         -1.94736842]]
# lefy:  2.053 right: -1.895
# slope_rightP : -2.6
# slope_leftP : 2.6
# slope_right : -1.895
# slope_left : 2.053
# slope : 0.158
#
# modeL [ 8 24 74 35]
# modeR [80 99 35 69 -2]
# allLeft:  [[16 29 74 35]
#  [ 9 26 74 35]
#  [ 8 25 74 35]
#  [17 31 74 35]
#  [ 8 24 71 35]]
# allRight:  [[80.         97.         35.         74.         -2.29411765]
#  [81.         99.         35.         71.         -2.        ]
#  [82.         99.         35.         69.         -2.        ]]
# lefy:  2.438 right: -1.789
# slope_rightP : -1.895
# slope_leftP : 2.053
# slope_right : -1.789
# slope_left : 2.438
# slope : 0.649
#
# modeL [ 8 23 74 35]
# modeR [79 97 35 72 -2]
# allLeft:  [[ 8 23 73 35]
#  [15 30 74 35]
#  [ 9 24 74 35]]
# allRight:  [[79.         97.         35.         74.         -2.16666667]
#  [80.         99.         35.         72.         -1.94736842]]
# lefy:  2.6 right: -2.056
# slope_rightP : -1.789
# slope_leftP : 2.438
# slope_right : -2.056
# slope_left : 2.6
# slope : 0.544
#
# modeL [ 8 23 74 35]
# modeR [75 99 35 70 -1]
# allLeft:  [[16 31 74 35]
#  [ 8 23 74 35]
#  [15 29 74 35]
#  [ 9 25 74 35]]
# allRight:  [[77.         99.         35.         70.         -1.59090909]
#  [75.         99.         35.         72.         -1.54166667]]
# lefy:  2.6 right: -1.458
# slope_rightP : -2.056
# slope_leftP : 2.6
# slope_right : -1.458
# slope_left : 2.6
# slope : 1.142
#
# modeL [ 7 23 74 35]
# modeR [77 99 35 72 -1]
# allLeft:  [[15 31 73 35]
#  [ 9 24 74 35]
#  [ 7 23 74 35]]
# allRight:  [[80.         99.         35.         72.         -1.94736842]
#  [77.         99.         35.         73.         -1.72727273]]
# lefy:  2.438 right: -1.682
# slope_rightP : -1.458
# slope_leftP : 2.6
# slope_right : -1.682
# slope_left : 2.438
# slope : 0.756
#
# modeL [ 7 23 74 35]
# modeR [77 99 35 71 -2]
# allLeft:  [[ 7 23 73 35]
#  [ 8 26 74 35]
#  [15 28 72 35]
#  [16 29 74 35]]
# allRight:  [[77.         99.         35.         73.         -1.72727273]
#  [81.         99.         35.         71.         -2.        ]]
# lefy:  2.438 right: -1.636
# slope_rightP : -1.682
# slope_leftP : 2.438
# slope_right : -1.636
# slope_left : 2.438
# slope : 0.802
#
# modeL [ 9 23 74 35]
# modeR [77 99 35 74 -1]
# allLeft:  [[16 30 74 35]
#  [ 9 23 74 35]
#  [15 29 74 35]]
# allRight:  [[77.         97.         35.         74.         -1.95      ]
#  [79.         99.         35.         74.         -1.95      ]
#  [81.         99.         35.         73.         -2.11111111]]
# lefy:  2.786 right: -1.773
# slope_rightP : -1.636
# slope_leftP : 2.438
# slope_right : -1.773
# slope_left : 2.786
# slope : 1.013
#
# modeL [ 7 26 74 35]
# modeR [77 99 35 70 -1]
# allLeft:  [[ 7 26 74 35]
#  [16 29 74 35]
#  [15 27 74 36]]
# allRight:  [[77.         99.         35.         70.         -1.59090909]]
# lefy:  2.053 right: -1.591
# slope_rightP : -1.773
# slope_leftP : 2.786
# slope_right : -1.591
# slope_left : 2.053
# slope : 0.462
#
# modeL [16 22 74 35]
# modeR [76 96 35 74 -2]
# allLeft:  [[ 8 23 74 35]
#  [16 28 74 35]
#  [ 7 22 74 36]
#  [16 27 73 35]]
# allRight:  [[79.         97.         35.         74.         -2.16666667]
#  [76.         96.         35.         74.         -1.95      ]
#  [81.         99.         35.         73.         -2.11111111]]
# lefy:  6.5 right: -1.95
# slope_rightP : -1.591
# slope_leftP : 2.053
# slope_right : -1.95
# slope_left : 6.5
# slope : 2
#
# modeL [ 6 22 74 35]
# modeR [77 95 35 73 -2]
# allLeft:  [[ 7 23 74 35]
#  [15 29 74 35]
#  [14 28 74 35]
#  [ 6 22 74 35]]
# allRight:  [[78.         99.         35.         73.         -1.80952381]
#  [77.         95.         35.         74.         -2.16666667]]
# lefy:  2.438 right: -2.111
# slope_rightP : -1.95
# slope_leftP : 6.5
# slope_right : -2.111
# slope_left : 2.438
# slope : 0.327
#
# modeL [ 6 23 74 35]
# modeR [75 99 35 72 -1]
# allLeft:  [[ 6 23 72 35]
#  [13 26 73 35]
#  [14 29 74 35]
#  [ 7 24 74 35]]
# allRight:  [[75.         99.         35.         74.         -1.625     ]
#  [77.         99.         35.         72.         -1.68181818]]
# lefy:  2.294 right: -1.542
# slope_rightP : -2.111
# slope_leftP : 2.438
# slope_right : -1.542
# slope_left : 2.294
# slope : 0.752
#
# modeL [12 20 73 35]
# modeR [73 99 35 72 -1]
# allLeft:  [[ 6 22 74 35]
#  [12 27 74 35]
#  [ 5 20 73 35]
#  [12 26 73 35]]
# allRight:  [[75.         99.         35.         73.         -1.58333333]
#  [73.         98.         35.         74.         -1.56      ]
#  [77.         99.         35.         72.         -1.68181818]]
# lefy:  4.75 right: -1.423
# slope_rightP : -1.542
# slope_leftP : 2.294
# slope_right : -1.423
# slope_left : 4.75
# slope : 2
#
# modeL [ 4 21 74 35]
# modeR [73 99 35 74 -1]
# allLeft:  [[ 4 21 73 35]
#  [ 4 21 74 36]
#  [12 26 74 35]
#  [11 24 74 35]]
# allRight:  [[73.         98.         35.         74.         -1.56      ]
#  [77.         99.         35.         73.         -1.72727273]
#  [74.         99.         35.         74.         -1.56      ]]
# lefy:  2.294 right: -1.5
# slope_rightP : -1.423
# slope_leftP : 4.75
# slope_right : -1.5
# slope_left : 2.294
# slope : 0.794
#
# modeL [ 4 18 74 35]
# modeR [73 97 35 74 -1]
# allLeft:  [[ 4 20 74 35]
#  [12 26 74 35]
#  [11 24 74 35]
#  [ 4 18 73 36]]
# allRight:  [[73.    97.    35.    74.    -1.625]
#  [78.    98.    35.    74.    -1.95 ]]
# lefy:  2.786 right: -1.625
# slope_rightP : -1.5
# slope_leftP : 2.294
# slope_right : -1.625
# slope_left : 2.786
# slope : 1.161
#
# modeL [ 4 18 74 35]
# modeR [73 96 35 74 -1]
# allLeft:  [[ 4 18 70 35]
#  [10 24 74 35]
#  [ 5 19 74 35]]
# allRight:  [[77.         98.         35.         74.         -1.85714286]
#  [73.         96.         35.         74.         -1.69565217]]
# lefy:  2.786 right: -1.696
# slope_rightP : -1.625
# slope_leftP : 2.786
# slope_right : -1.696
# slope_left : 2.786
# slope : 1.09
#
# modeL [ 3 17 74 35]
# modeR [72 98 35 73 -1]
# allLeft:  [[ 9 23 74 35]
#  [ 4 19 74 35]
#  [ 3 17 74 35]
#  [11 25 74 35]]
# allRight:  [[73.   98.   35.   73.   -1.52]
#  [72.   98.   35.   74.   -1.5 ]]
# lefy:  2.786 right: -1.462
# slope_rightP : -1.696
# slope_leftP : 2.786
# slope_right : -1.462
# slope_left : 2.786
# slope : 1.324
#
# modeL [ 3 18 74 35]
# modeR [71 98 35 74 -1]
# allLeft:  [[ 9 23 74 35]
#  [ 3 18 73 35]
#  [ 4 19 74 35]]
# allRight:  [[76.         98.         35.         72.         -1.68181818]
#  [73.         95.         35.         74.         -1.77272727]
#  [75.         98.         35.         74.         -1.69565217]
#  [71.         94.         35.         74.         -1.69565217]]
# lefy:  2.6 right: -1.444
# slope_rightP : -1.462
# slope_leftP : 2.786
# slope_right : -1.444
# slope_left : 2.6
# slope : 1.156
#
# modeL [ 3 17 74 35]
# modeR [71 91 35 74 -1]
# allLeft:  [[ 4 18 74 35]
#  [ 9 23 74 35]
#  [ 3 17 74 36]]
# allRight:  [[75.         92.         35.         74.         -2.29411765]
#  [76.         96.         35.         74.         -1.95      ]
#  [71.         91.         35.         74.         -1.95      ]]
# lefy:  2.786 right: -1.95
# slope_rightP : -1.444
# slope_leftP : 2.6
# slope_right : -1.95
# slope_left : 2.786
# slope : 0.836
#
# modeL [ 2 17 74 35]
# modeR [70 97 35 71 -1]
# allLeft:  [[ 4 19 74 35]
#  [ 9 22 74 35]
#  [ 2 17 74 36]]
# allRight:  [[70.         97.         35.         73.         -1.40740741]
#  [73.         97.         35.         71.         -1.5       ]]
# lefy:  2.6 right: -1.333
# slope_rightP : -1.95
# slope_leftP : 2.786
# slope_right : -1.333
# slope_left : 2.6
# slope : 1.267
# modeL [ 3 18 74 35]
# modeR [70 97 35 74 -1]
# allLeft:  [[ 3 18 74 35]
#  [10 23 74 35]
#  [ 9 21 74 35]
#  [ 4 20 74 35]]
# allRight:  [[70.         97.         35.         71.         -1.33333333]
#  [73.         97.         35.         74.         -1.625     ]
#  [71.         91.         35.         74.         -1.95      ]]
# lefy:  2.6 right: -1.444
# slope_rightP : -1.333
# slope_leftP : 2.6
# slope_right : -1.444
# slope_left : 2.6
# slope : 1.156
#
# modeL [ 3 18 74 35]
# modeR [74 91 35 74 -2]
# allLeft:  [[ 3 21 74 35]
#  [ 3 18 73 35]
#  [10 23 74 35]
#  [11 24 72 35]]
# allRight:  [[76.         96.         35.         74.         -1.95      ]
#  [74.         91.         35.         74.         -2.29411765]
#  [75.         92.         36.         74.         -2.23529412]
#  [78.         97.         36.         73.         -1.94736842]]
# lefy:  2.6 right: -2.294
# slope_rightP : -1.444
# slope_leftP : 2.6
# slope_right : -2.294
# slope_left : 2.6
# slope : 0.306
#
# modeL [10 19 74 35]
# modeR [70 97 35 71 -1]
# allLeft:  [[ 4 19 74 35]
#  [10 24 74 35]
#  [10 23 72 35]]
# allRight:  [[71.         97.         35.         73.         -1.46153846]
#  [70.         97.         35.         74.         -1.44444444]
#  [75.         97.         35.         71.         -1.63636364]]
# lefy:  4.333 right: -1.333
# slope_rightP : -2.294
# slope_leftP : 2.6
# slope_right : -1.333
# slope_left : 4.333
# slope : 2
#
# modeL [ 3 20 74 35]
# modeR [71 93 35 72 -2]
# allLeft:  [[11 25 74 35]
#  [ 3 20 74 35]
#  [10 23 73 35]
#  [ 5 21 74 35]]
# allRight:  [[78.         93.         35.         74.         -2.6       ]
#  [71.         97.         35.         72.         -1.42307692]]
# lefy:  2.294 right: -1.682
# slope_rightP : -1.333
# slope_leftP : 4.333
# slope_right : -1.682
# slope_left : 2.294
# slope : 0.612
#
# modeL [10 21 74 35]
# modeR [72 93 35 74 -1]
# allLeft:  [[ 4 21 74 35]
#  [10 25 74 35]
#  [12 26 74 35]
#  [10 23 73 35]]
# allRight:  [[77.         97.         35.         74.         -1.95      ]
#  [73.         95.         35.         74.         -1.77272727]
#  [76.         96.         35.         74.         -1.95      ]
#  [79.         98.         36.         73.         -1.94736842]
#  [72.         93.         35.         73.         -1.80952381]]
# lefy:  3.545 right: -1.857
# slope_rightP : -1.682
# slope_leftP : 2.294
# slope_right : -1.857
# slope_left : 3.545
# slope : 1.688
#
# modeL [ 4 23 73 35]
# modeR [73 94 35 74 -1]
# allLeft:  [[ 4 23 73 35]
#  [11 25 74 35]]
# allRight:  [[76.         97.         35.         74.         -1.85714286]
#  [73.         94.         35.         74.         -1.85714286]
#  [78.         98.         36.         74.         -1.9       ]]
# lefy:  2.0 right: -1.857
# slope_rightP : -1.857
# slope_leftP : 3.545
# slope_right : -1.857
# slope_left : 2.0
# slope : 0.143
#
# modeL [ 4 23 72 35]
# modeR [74 92 35 74 -2]
# allLeft:  [[ 4 23 72 35]
#  [12 25 74 35]
#  [11 24 73 35]]
# allRight:  [[76.         93.         35.         74.         -2.29411765]
#  [74.         92.         35.         74.         -2.16666667]
#  [77.         96.         36.         69.         -1.73684211]]
# lefy:  1.947 right: -2.167
# slope_rightP : -1.857
# slope_leftP : 2.0
# slope_right : -2.167
# slope_left : 1.947
# slope : -0.22
#
# modeL [ 4 20 74 35]
# modeR [72 97 35 74 -1]
# allLeft:  [[ 4 20 74 35]
#  [11 25 74 35]
#  [13 26 74 35]
#  [ 6 22 74 35]]
# allRight:  [[76.         97.         35.         74.         -1.85714286]
#  [72.         93.         35.         74.         -1.85714286]
#  [73.         95.         35.         74.         -1.77272727]
#  [77.         97.         36.         71.         -1.75      ]]
# lefy:  2.438 right: -1.56
# slope_rightP : -2.167
# slope_leftP : 1.947
# slope_right : -1.56
# slope_left : 2.438
# slope : 0.878
#
# modeL [11 20 74 35]
# modeR [72 96 35 70 -1]
# allLeft:  [[11 24 72 35]
#  [11 25 74 35]
#  [ 5 22 74 35]
#  [ 4 20 74 35]]
# allRight:  [[74.         97.         35.         70.         -1.52173913]
#  [72.         96.         35.         74.         -1.625     ]]
# lefy:  4.333 right: -1.458
# slope_rightP : -1.56
# slope_leftP : 2.438
# slope_right : -1.458
# slope_left : 4.333
# slope : 2
#
# modeL [ 4 20 74 35]
# modeR [71 98 35 72 -1]
# allLeft:  [[10 27 74 35]
#  [ 5 21 74 35]
#  [ 4 20 74 35]]
# allRight:  [[73.         98.         35.         72.         -1.48      ]
#  [71.         98.         35.         73.         -1.40740741]]
# lefy:  2.438 right: -1.37
# slope_rightP : -1.458
# slope_leftP : 4.333
# slope_right : -1.37
# slope_left : 2.438
# slope : 1.068
#
# modeL [ 4 23 72 35]
# modeR [71 98 35 72 -1]
# allLeft:  [[11 27 72 35]
#  [ 4 23 74 35]]
# allRight:  [[71.         98.         35.         73.         -1.40740741]
#  [75.         98.         35.         72.         -1.60869565]]
# lefy:  1.947 right: -1.37
# slope_rightP : -1.37
# slope_leftP : 2.438
# slope_right : -1.37
# slope_left : 1.947
# slope : 0.577
#
# modeL [ 4 21 74 35]
# modeR [72 96 35 71 -1]
# allLeft:  [[ 4 21 74 35]
#  [12 26 74 35]
#  [11 25 74 35]]
# allRight:  [[72.         96.         35.         74.         -1.625     ]
#  [75.         97.         35.         71.         -1.63636364]
#  [73.         98.         35.         73.         -1.52      ]]
# lefy:  2.294 right: -1.5
# slope_rightP : -1.37
# slope_leftP : 1.947
# slope_right : -1.5
# slope_left : 2.294
# slope : 0.794
#
# modeL [ 3 22 74 35]
# modeR [73 92 35 74 -1]
# allLeft:  [[12 26 74 35]
#  [ 3 22 74 35]
#  [11 25 74 35]
#  [10 23 73 35]]
# allRight:  [[73.         92.         35.         72.         -1.94736842]
#  [77.         97.         35.         74.         -1.95      ]
#  [75.         96.         35.         74.         -1.85714286]]
# lefy:  2.053 right: -2.053
# slope_rightP : -1.5
# slope_leftP : 2.294
# slope_right : -2.053
# slope_left : 2.053
# slope : 0.0
#
# modeL [ 3 20 74 35]
# modeR [73 91 35 68 -2]
# allLeft:  [[11 24 74 35]
#  [ 3 20 74 35]
#  [ 4 21 74 35]
#  [10 23 74 35]]
# allRight:  [[76.         97.         35.         74.         -1.85714286]
#  [74.         91.         35.         68.         -1.94117647]
#  [73.         92.         35.         73.         -2.        ]]
# lefy:  2.294 right: -1.833
# slope_rightP : -2.053
# slope_leftP : 2.053
# slope_right : -1.833
# slope_left : 2.294
# slope : 0.461
#
# modeL [ 3 25 74 35]
# modeR [72 92 35 70 -1]
# allLeft:  [[10 25 74 35]
#  [ 4 22 74 35]
#  [11 25 74 36]
#  [ 3 19 74 35]]
# allRight:  [[76.         97.         35.         74.         -1.85714286]
#  [73.         92.         35.         70.         -1.84210526]
#  [72.         92.         35.         73.         -1.9       ]]
# lefy:  1.773 right: -1.75
# slope_rightP : -1.833
# slope_leftP : 2.294
# slope_right : -1.75
# slope_left : 1.773
# slope : 0.023
#
# modeL [ 3 21 74 35]
# modeR [72 92 35 74 -1]
# allLeft:  [[ 3 22 74 35]
#  [10 24 74 35]
#  [ 3 21 72 35]]
# allRight:  [[73.   93.   35.   73.   -1.9 ]
#  [76.   96.   35.   74.   -1.95]
#  [77.   97.   35.   74.   -1.95]
#  [72.   92.   35.   74.   -1.95]]
# lefy:  2.167 right: -1.95
# slope_rightP : -1.75
# slope_leftP : 1.773
# slope_right : -1.95
# slope_left : 2.167
# slope : 0.217
#
# modeL [ 3 19 74 35]
# modeR [72 92 35 74 -2]
# allLeft:  [[10 23 74 35]
#  [ 3 19 74 35]
#  [ 4 20 74 35]
#  [11 24 72 35]]
# allRight:  [[74.         93.         35.         74.         -2.05263158]
#  [75.         96.         35.         74.         -1.85714286]
#  [77.         97.         36.         74.         -1.9       ]
#  [72.         92.         35.         74.         -1.95      ]]
# lefy:  2.438 right: -1.95
# slope_rightP : -1.95
# slope_leftP : 2.167
# slope_right : -1.95
# slope_left : 2.438
# slope : 0.488
#
# modeL [ 3 20 74 35]
# modeR [71 95 35 74 -1]
# allLeft:  [[ 3 20 74 35]
#  [10 24 74 35]]
# allRight:  [[73.         93.         35.         74.         -1.95      ]
#  [71.         91.         35.         74.         -1.95      ]
#  [75.         95.         35.         67.         -1.6       ]
#  [74.         95.         35.         71.         -1.71428571]]
# lefy:  2.294 right: -1.625
# slope_rightP : -1.95
# slope_leftP : 2.438
# slope_right : -1.625
# slope_left : 2.294
# slope : 0.669
#
# modeL [ 3 20 74 35]
# modeR [71 96 35 70 -1]
# allLeft:  [[ 3 20 74 35]
#  [10 23 74 35]
#  [11 24 72 35]]
# allRight:  [[73.         96.         35.         73.         -1.65217391]
#  [71.         91.         35.         74.         -1.95      ]
#  [75.         96.         35.         70.         -1.66666667]]
# lefy:  2.294 right: -1.4
# slope_rightP : -1.625
# slope_leftP : 2.294
# slope_right : -1.4
# slope_left : 2.294
# slope : 0.894
#
# modeL [ 3 19 74 35]
# modeR [72 96 35 71 -1]
# allLeft:  [[ 3 21 74 35]
#  [10 25 74 35]
#  [ 9 23 74 35]
#  [ 3 19 73 35]]
# allRight:  [[73.         96.         35.         73.         -1.65217391]
#  [75.         96.         35.         71.         -1.71428571]
#  [72.         92.         35.         74.         -1.95      ]]
# lefy:  2.438 right: -1.5
# slope_rightP : -1.4
# slope_leftP : 2.294
# slope_right : -1.5
# slope_left : 2.438
# slope : 0.938
# slope_rightP : -1.4
# slope_leftP : 2.294
# slope_right : -1.5
# slope_left : 2.438
# slope : 0.938
